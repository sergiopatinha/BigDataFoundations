# %% [markdown]
# ### 1 Introduction and Setup
# #### 1.1 Introduction
#
# <span style="font-size:20px;"><b>Cinema Battle Cup — Introduction</b></span>
#
# This section presents a small, playful competition designed to demonstrate concepts from the Big Data Foundations course while working with a large-scale, multi-source movie dataset. The goal was to build a “World Cup–style” knockout tournament between well-known cinema characters — heroes and villains — using real metrics enriched from two different data sources: **MovieLens** and **IMDB**.
#
# Although the set of characters was manually selected by the user, all numerical attributes used in the competition were derived through data enrichment techniques applied to the movies in which these characters appear.
#
# <span style="font-size:20px;"><b>Big Data Foundations Context: Data Preparation & Enrichment</b></span>
#
# Before running the competition, several steps aligned with the course methodology were performed:
#
# **1. Conversion of raw datasets to Parquet:**
#
# All MovieLens and IMDB datasets were transformed into Parquet files, taking advantage of:
#  - columnar storage
#  - efficient compression
#  - faster analytical queries
#  - better integration with DuckDB
#
# This is a core aspect of scalable data processing discussed in the course.
#
# **2. Integration of MovieLens and IMDB via DuckDB:**
#
# Using DuckDB, multiple views were created on top of the full IMDB dataset.
# However, to avoid unnecessary storage and processing, only the IMDB movies that had a valid correspondence to the original MovieLens dataset (via imdbId → tconst) were materialized into new tables/views.
#
# This ensured that the enriched dataset remained:
#  - compact
#  - relevant
#  - faster to query
#
# **3. Data Enrichment:**
#
# For each character, the system aggregated information from both sources:
#
#  - ml_ratings_count — number of ratings on MovieLens
#  - imdb_ratings_count — number of ratings on IMDB
#  - ml_average_rating — average rating on MovieLens
# - imdb_average_rating — average rating on IMDB
#
# These metrics allowed us to compare characters based on the popularity and quality of the movies they appear in — a direct application of multi-source data enrichment.
#
# <span style="font-size:20px;"><b>Competition Structure</b></span>
#
# The tournament is split into two groups:
#
#  - df_characters_heroes — eight iconic heroes
#  - df_characters_villains — eight famous villains
#
# Each group follows a knockout format until one champion remains.
# Finally, the two champions face each other in the grand final.
#
# **First Round — From Top 8 to Top 4**
#
# Randomised match-ups (using a fixed seed for reproducibility).
# Winner = character with the highest:
#
# > ml_ratings_count + imdb_ratings_count
#
# This favours characters appearing in highly viewed or popular films.
#
# **Second Round — From Top 4 to Top 2**
#
# Winner = character with the highest weighted rating:
#
# > 0.5 × ml_average_rating + 0.5 × imdb_average_rating
#
# This rewards characters associated with well-rated films.
#
# **Third Round — Final of Each Category (Top 2 → Winner)**
#
# Winner = character with the strongest combined impact:
#
# >(ml_average_rating × ml_ratings_count) + (imdb_average_rating × imdb_ratings_count)
#
# This incorporates both rating volume and rating quality.
#
# **Final — Hero Champion vs. Villain Champion**
#
# The winners of each category face off using the same metric as the third round.
#
# <span style="font-size:20px;"><b>Reproducibility</b></span>
#
# The random shuffling of match-ups uses a fixed seed, ensuring the entire competition can be reproduced exactly.
#
#
#
#
# #### 1.2 Library and duckdb file import

# %%
#================================================
# DATA
#================================================

import duckdb, pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

# creating the conection to the duckdb database file:
con = duckdb.connect("movielensfull33M.duckdb")

# %%
IMDB_DIR = Path("..") / "data" / "Imdb"
IMDB_DIR
# Out:
# WindowsPath('../data/Imdb')

# %% [markdown]
# ### 2 Functions to help in the search for all time know Characters
# #### 2.1 Ad-hoc Query Characters and actors_name by movieID

# %%
def search_by_movie_id(movie_id):
    query = """
        WITH ml_ratings AS (
            SELECT
                movieId,
                AVG(rating) AS ml_avg_rating,
                COUNT(*) AS ml_ratings_count
            FROM ratings
            GROUP BY movieId
        ),
        imdb_ratings AS (
            SELECT
                movieId,
                averageRating / 2 AS imdb_avg_rating,
                numVotes AS imdb_ratings_count
            FROM movielens_ratings_imdb
        )
        SELECT
            a.movieId,
            a.characters,
            a.actor_name,
            a.title AS movie_title,
            ROUND(mr.ml_avg_rating, 2) AS ml_avg_rating,
            mr.ml_ratings_count,
            ir.imdb_avg_rating,
            ir.imdb_ratings_count
        FROM movielens_actors AS a
        LEFT JOIN ml_ratings AS mr
            ON mr.movieId = a.movieId
        LEFT JOIN imdb_ratings AS ir
            ON ir.movieId = a.movieId
        WHERE a.movieId = ?
        ORDER BY movie_title, actor_name;
    """
    
    return con.execute(query, [movie_id]).df()

# %% [markdown]
# #### 2.2 Function to search movies by Characters

# %%
def search_by_character(character):
    query = """
        WITH ml_ratings AS (
            SELECT
                movieId,
                AVG(rating) AS ml_avg_rating,
                COUNT(*)    AS ml_ratings_count
            FROM ratings
            GROUP BY movieId
        ),
        imdb_ratings AS (
            SELECT
                movieId,
                averageRating/2 AS imdb_avg_rating,
                numVotes      AS imdb_ratings_count
            FROM movielens_ratings_imdb
        )
        SELECT
            a.movieId,
            a.characters,
            a.actor_name,
            a.title AS movie_title,
            ROUND(mr.ml_avg_rating, 2) AS ml_avg_rating,
            mr.ml_ratings_count,
            ir.imdb_avg_rating,
            ir.imdb_ratings_count
        FROM movielens_actors AS a
        LEFT JOIN ml_ratings AS mr
            ON mr.movieId = a.movieId
        LEFT JOIN imdb_ratings AS ir
            ON ir.movieId = a.movieId
        WHERE LOWER(a.characters) LIKE LOWER('%' || ? || '%')
        ORDER BY movie_title, actor_name;
    """
    return con.execute(query, [character]).df()

# %% [markdown]
# #### 2.3 Function to search movies by Characters and movies title

# %%
def search_by_character_and_movies(character, movie_title):
    query = """
        WITH ml_ratings AS (
            SELECT
                movieId,
                AVG(rating) AS ml_avg_rating,
                COUNT(*) AS ml_ratings_count
            FROM ratings
            GROUP BY movieId
        ),
        imdb_ratings AS (
            SELECT
                movieId,
                averageRating / 2 AS imdb_avg_rating,
                numVotes AS imdb_ratings_count
            FROM movielens_ratings_imdb
        )
        SELECT
            a.movieId,
            a.characters,
            a.actor_name,
            a.title AS movie_title,
            ROUND(mr.ml_avg_rating, 2) AS ml_avg_rating,
            mr.ml_ratings_count,
            ir.imdb_avg_rating,
            ir.imdb_ratings_count
        FROM movielens_actors AS a
        LEFT JOIN ml_ratings AS mr
            ON mr.movieId = a.movieId
        LEFT JOIN imdb_ratings AS ir
            ON ir.movieId = a.movieId
        WHERE LOWER(a.characters) LIKE LOWER('%' || ? || '%')
          AND LOWER(a.title) LIKE LOWER('%' || ? || '%')
        ORDER BY movie_title, actor_name;
    """
    
    return con.execute(query, [character, movie_title]).df()

# %% [markdown]
# #### 2.4 Function to search movies by Characters and actor name

# %%
def search_by_character_and_actor(character, actor_name):
    query = """
        WITH ml_ratings AS (
            SELECT
                movieId,
                AVG(rating) AS ml_avg_rating,
                COUNT(*) AS ml_ratings_count
            FROM ratings
            GROUP BY movieId
        ),
        imdb_ratings AS (
            SELECT
                movieId,
                averageRating / 2 AS imdb_avg_rating,
                numVotes AS imdb_ratings_count
            FROM movielens_ratings_imdb
        )
        SELECT
            a.movieId,
            a.characters,
            a.actor_name,
            a.title AS movie_title,
            ROUND(mr.ml_avg_rating, 2) AS ml_avg_rating,
            mr.ml_ratings_count,
            ir.imdb_avg_rating,
            ir.imdb_ratings_count
        FROM movielens_actors AS a
        LEFT JOIN ml_ratings AS mr
            ON mr.movieId = a.movieId
        LEFT JOIN imdb_ratings AS ir
            ON ir.movieId = a.movieId
        WHERE LOWER(a.characters) LIKE LOWER('%' || ? || '%')
          AND LOWER(a.actor_name) LIKE LOWER('%' || ? || '%')
        ORDER BY movie_title, actor_name;
    """
    
    return con.execute(query, [character, actor_name]).df()

# %% [markdown]
# #### 2.5 Function to summarize functions of the result dataframes

# %%
import pandas as pd
import numpy as np

def summarize_character(df, character_name=None):
    """
    Summarize a dataframe (from your search_* functions)
    into a single-row dataframe with weighted averages
    for ML and IMDb ratings.
    """
    if df.empty:
        return pd.DataFrame([{
            "character": character_name,
            "movies_count": 0,
            "character_avg_rating": np.nan,
            "character_rating_count": 0,
            "character_imdb_rating": np.nan,
            "character_imdb_count": 0,
        }])
    
    # If character_name is not provided, try to infer it from the dataframe
    if character_name is None:
        # Take the most common or first character string
        character_name = df["characters"].iloc[0]
    
    # 1) number of distinct movies
    movies_count = df["movieId"].nunique()
    
    # 2) total ML ratings count
    character_rating_count = df["ml_ratings_count"].fillna(0).sum()
    
    # 3) weighted average ML rating
    #    sum(ml_avg_rating * ml_ratings_count) / sum(ml_ratings_count)
    ml_weights = df["ml_ratings_count"].fillna(0)
    ml_values = df["ml_avg_rating"]
    if (ml_weights > 0).any():
        character_avg_rating = (ml_values * ml_weights).sum() / ml_weights.sum()
    else:
        character_avg_rating = np.nan
    
    # 4) total IMDb ratings count
    character_imdb_count = df["imdb_ratings_count"].fillna(0).sum()
    
    # 5) weighted average IMDb rating
    imdb_weights = df["imdb_ratings_count"].fillna(0)
    imdb_values = df["imdb_avg_rating"]
    if (imdb_weights > 0).any():
        character_imdb_rating = (imdb_values * imdb_weights).sum() / imdb_weights.sum()
    else:
        character_imdb_rating = np.nan
    
    # Build single-row dataframe
    summary = pd.DataFrame([{
        "character": character_name,
        "movies_count": movies_count,
        "character_avg_rating": character_avg_rating,
        "character_rating_count": character_rating_count,
        "character_imdb_rating": character_imdb_rating,
        "character_imdb_count": character_imdb_count,
    }])
    
    return summary

# %% [markdown]
# ### 3 Bigest Heroes Ever
# #### 3.1 Batman

# %%
df=search_by_character_and_movies("batman", "batman")
df
# Out:
#     movieId  characters         actor_name  \
# 0    176681      Batman       Kevin Conroy
# 1      1562      Batman     George Clooney
# 2     91054      Batman       Lewis Wilson
# 3     26152      Batman          Adam West
# 4       592      Batman     Michael Keaton
# 5     33794      Batman     Christian Bale
# 6    167762      Batman       Will Friedle
# 7    174957      Batman       Kevin Conroy
# 8    174957      Batman       Will Friedle
# 9       153      Batman         Val Kilmer
# 10   186985      Batman    Kôichi Yamadera
# 11     1377      Batman     Michael Keaton
# 12   132656      Batman  Roger Craig Smith
# 13   163476      Batman  Roger Craig Smith
# 14   140115      Batman  Roger Craig Smith
# 15    91056      Batman      Robert Lowery
# 16   136864      Batman        Ben Affleck
# 17   131739      Batman       Jason O'Mara
# 18   202099      Batman         Troy Baker
# 19   178997      Batman          Adam West
# 20   151345      Batman       Jason O'Mara
# 21   182613      Batman      Clark Bartram
# 22   183915      Batman    Bruce Greenwood
# 23   200864      Batman       Jason O'Mara
# 24     3213      Batman       Kevin Conroy
# 25   165085      Batman          Adam West
# 26   167764      Batman       Kevin Conroy
# 27   161354      Batman       Kevin Conroy
# 28   165153      Batman         Troy Baker
# 29   183455      Batman     Diedrich Bader
# 30   268642  The Batman   Robert Pattinson
# 31   118173  The Batman        Rino Romano
# 32   167746      Batman        Will Arnett
#
#                                           movie_title  ml_avg_rating  \
# 0                        Batman & Harley Quinn (2017)           2.84
# 1                               Batman & Robin (1997)           2.19
# 2                                       Batman (1943)           2.95
# 3                                       Batman (1966)           3.21
# 4                                       Batman (1989)           3.39
# 5                                Batman Begins (2005)           3.92
# 6   Batman Beyond Darwyn Cooke's Batman 75th Anniv...           3.35
# 7                     Batman Beyond: The Movie (1999)           3.51
# 8                     Batman Beyond: The Movie (1999)           3.51
# 9                               Batman Forever (1995)           2.89
# 10                                Batman Ninja (2018)           2.96
# 11                              Batman Returns (1992)           3.14
# 12          Batman Unlimited: Animal Instincts (2015)           2.24
# 13          Batman Unlimited: Mech vs. Mutants (2016)           2.60
# 14            Batman Unlimited: Monster Mayhem (2015)           2.09
# 15                            Batman and Robin (1949)           2.97
# 16          Batman v Superman: Dawn of Justice (2016)           2.70
# 17                            Batman vs. Robin (2015)           3.29
# 18     Batman vs. Teenage Mutant Ninja Turtles (2019)           3.38
# 19                         Batman vs. Two-Face (2017)           2.66
# 20                           Batman: Bad Blood (2016)           3.34
# 21                            Batman: Dead End (2003)           3.09
# 22                  Batman: Gotham by Gaslight (2018)           3.19
# 23                                Batman: Hush (2019)           3.03
# 24                Batman: Mask of the Phantasm (1993)           3.52
# 25       Batman: Return of the Caped Crusaders (2016)           2.88
# 26                        Batman: Strange Days (2014)           3.01
# 27                    Batman: The Killing Joke (2016)           3.00
# 28  LEGO DC Comics Super Heroes: Batman: Be-League...           2.63
# 29  Scooby-Doo! & Batman: The Brave and the Bold (...           2.76
# 30                                  The Batman (2022)           3.69
# 31                      The Batman vs. Dracula (2005)           2.96
# 32                       The Lego Batman Movie (2017)           3.58
#
#     ml_ratings_count  imdb_avg_rating  imdb_ratings_count
# 0                119             2.95               16283
# 1              12649             1.90              279184
# 2                 31             3.00                2690
# 3               1092             3.25               37499
# 4              56330             3.75              426194
# 5              43300             4.10             1679844
# 6                 52             3.90                2667
# 7                 59             3.85                6901
# 8                 59             3.85                6901
# 9              40052             2.75              278849
# 10               199             2.80               23774
# 11             16558             3.55              345431
# 12                39             2.85                3652
# 13                10             2.90                2090
# 14                40             2.80                3347
# 15                34             2.95                2250
# 16              4625             3.20              782923
# 17               229             3.55               27809
# 18                85             3.55               13701
# 19                53             3.10                4929
# 20               238             3.35               27975
# 21                23             3.60                6367
# 22               159             3.35               20264
# 23               143             3.45               25102
# 24              2383             3.90               62076
# 25                76             3.35                6869
# 26                35             3.70                2086
# 27               524             3.20               64721
# 28                15             3.20                1777
# 29                25             3.25                3681
# 30              3366             3.90              901316
# 31                79             3.30               12199
# 32              2294             3.65              187623

# %%
df_characters_heroes = summarize_character(df)
df_characters_heroes
# Out:
#   character  movies_count  character_avg_rating  character_rating_count  \
# 0    Batman            32              3.288466                  184975
#
#    character_imdb_rating  character_imdb_count
# 0               3.611069               5268974

# %% [markdown]
# #### 3.2 Superman

# %%
df=search_by_character_and_movies("superman", "superman")
df
# Out:
#     movieId        characters            actor_name  \
# 0    157631          Superman        Hwang Jung-min
# 1    157631  Superman - child         Woo-hyuk Choi
# 2    140415          Superman             Kirk Alyn
# 3    136864          Superman          Henry Cavill
# 4    140439          Superman  David Patrick Wilson
# 5    219488          Superman         George Reeves
# 6    140417          Superman             Kirk Alyn
# 7      2640          Superman     Christopher Reeve
# 8    217461          Superman              Tim Daly
# 9      2641          Superman     Christopher Reeve
# 10     2642          Superman     Christopher Reeve
# 11     2643          Superman     Christopher Reeve
# 12    46530          Superman         Brandon Routh
# 13    89881          Superman         George Reeves
# 14   167780          Superman        George Newbern
# 15   136253          Superman              Tim Daly
# 16   205813          Superman           David Lodge
# 17   190017          Superman       Jerry O'Connell
#
#                                           movie_title  ml_avg_rating  \
# 0                       A Man Who Was Superman (2008)           3.47
# 1                       A Man Who Was Superman (2008)           3.47
# 2                         Atom Man vs Superman (1950)           2.60
# 3           Batman v Superman: Dawn of Justice (2016)           2.70
# 4    It's A Bird, It's A Plane, It's Superman! (1975)           1.83
# 5                       Stamp Day for Superman (1954)           4.00
# 6                                     Superman (1948)           2.78
# 7                                     Superman (1978)           3.38
# 8           Superman - The Last Son of Krypton (1996)           3.83
# 9                                  Superman II (1980)           3.10
# 10                                Superman III (1983)           2.48
# 11            Superman IV: The Quest for Peace (1987)           2.07
# 12                            Superman Returns (2006)           2.88
# 13                   Superman and the Mole-Men (1951)           2.62
# 14  Superman/Shazam!: The Return of Black Adam (2010)           3.18
# 15                  Superman: Brainiac Attacks (2006)           2.74
# 16                           Superman: Red Son (2009)           3.50
# 17                              The Death of Superman           3.31
#
#     ml_ratings_count  imdb_avg_rating  imdb_ratings_count
# 0                 19             3.60                2350
# 1                 19             3.60                2350
# 2                  5             3.30                 923
# 3               4625             3.20              782923
# 4                  3             1.90                 482
# 5                  3             2.70                 526
# 6                  9             3.35                1359
# 7              18453             3.70              204761
# 8                  6             3.80                3401
# 9              10622             3.40              123048
# 10              6111             2.50               80281
# 11              4065             1.90               57541
# 12              6252             3.05              301022
# 13                34             2.75                2671
# 14                51             3.50                9885
# 15                29             2.90                5354
# 16                 2             3.50                1260
# 17               148             3.65               21669

# %%
summary_df = summarize_character(df)
df_characters_heroes = pd.concat([df_characters_heroes, summary_df], ignore_index=True)

# %% [markdown]
# #### 3.3 James Bond

# %%
df= search_by_character("james bond")
df
# Out:
#     movieId                         characters            actor_name  \
# 0    258113                         James Bond        Bullet Prakash
# 1    262133                         James Bond          Barry Nelson
# 2      5796                     Sir James Bond           David Niven
# 3      5796  Evelyn Tremble (James Bond - 007)         Peter Sellers
# 4     49272                         James Bond          Daniel Craig
# 5      3984                         James Bond          Sean Connery
# 6      5872                         James Bond        Pierce Brosnan
# 7      2949                         James Bond          Sean Connery
# 8      2989                         James Bond           Roger Moore
# 9      2948                         James Bond          Sean Connery
# 10       10                         James Bond        Pierce Brosnan
# 11     2947                         James Bond          Sean Connery
# 12     2990                         James Bond        Timothy Dalton
# 13     2991                         James Bond           Roger Moore
# 14     4005                         James Bond        Timothy Dalton
# 15     3639                         James Bond           Roger Moore
# 16     3638                         James Bond           Roger Moore
# 17     7573                         James Bond          Sean Connery
# 18   224280                         James Bond          Daniel Craig
# 19     7570                         James Bond           Roger Moore
# 20     3633                         James Bond        George Lazenby
# 21    63113                         James Bond          Daniel Craig
# 22    96079                         James Bond          Daniel Craig
# 23   136020                         James Bond          Daniel Craig
# 24     3635                         James Bond           Roger Moore
# 25   161618                         James Bond       Alexander Grand
# 26   287425                         James Bond  Chae-Jamal McFarlane
# 27   287425         James Bond - Ornithologist         Gregory Itzin
# 28     2993                         James Bond          Sean Connery
# 29     1722                         James Bond        Pierce Brosnan
# 30     2376                         James Bond           Roger Moore
# 31     3082                         James Bond        Pierce Brosnan
# 32     7569                         James Bond          Sean Connery
#
#                                movie_title  ml_avg_rating  ml_ratings_count  \
# 0                         Bajarangi (2013)           3.50                 1
# 1                     Casino Royale (1954)           2.50                 1
# 2                     Casino Royale (1967)           2.88              1120
# 3                     Casino Royale (1967)           2.88              1120
# 4                     Casino Royale (2006)           3.84             28517
# 5              Diamonds Are Forever (1971)           3.50              5992
# 6                   Die Another Day (2002)           3.09              8720
# 7                            Dr. No (1962)           3.67              9694
# 8                For Your Eyes Only (1981)           3.44              5212
# 9             From Russia with Love (1963)           3.69              9586
# 10                        GoldenEye (1995)           3.43             34942
# 11                       Goldfinger (1964)           3.73             15527
# 12                  Licence to Kill (1989)           3.22              5313
# 13                 Live and Let Die (1973)           3.49              6294
# 14            Living Daylights, The (1987)           3.29              2731
# 15     Man with the Golden Gun, The (1974)           3.46              5037
# 16                        Moonraker (1979)           3.16              6014
# 17            Never Say Never Again (1983)           3.27              1556
# 18                   No Time to Die (2020)           3.48              1626
# 19                        Octopussy (1983)           3.31              2332
# 20  On Her Majesty's Secret Service (1969)           3.43              3605
# 21                Quantum of Solace (2008)           3.30             10196
# 22                          Skyfall (2012)           3.74             15918
# 23                          Spectre (2015)           3.39              5630
# 24            Spy Who Loved Me, The (1977)           3.53              5609
# 25           The Dragon Lives Again (1977)           0.50                 1
# 26                 The Other Fellow (2023)           3.50                 1
# 27                 The Other Fellow (2023)           3.50                 1
# 28                      Thunderball (1965)           3.60              5690
# 29              Tomorrow Never Dies (1997)           3.23             15919
# 30                View to a Kill, A (1985)           3.18              4526
# 31         World Is Not Enough, The (1999)           3.20             11583
# 32              You Only Live Twice (1967)           3.59              3394
#
#     imdb_avg_rating  imdb_ratings_count
# 0              3.00                 496
# 1              2.80                1658
# 2              2.50               34312
# 3              2.50               34312
# 4              4.00              729832
# 5              3.25              120225
# 6              3.05              237203
# 7              3.60              189896
# 8              3.35              113752
# 9              3.65              154124
# 10             3.60              281209
# 11             3.85              212708
# 12             3.35              117716
# 13             3.35              121680
# 14             3.35              111860
# 15             3.35              118942
# 16             3.15              114829
# 17             3.05               76351
# 18             3.65              474989
# 19             3.25              118508
# 20             3.35              105566
# 21             3.25              489086
# 22             3.90              760784
# 23             3.40              487455
# 24             3.50              122352
# 25             2.75                 521
# 26             3.20                 220
# 27             3.20                 220
# 28             3.45              134087
# 29             3.25              212455
# 30             3.15              110276
# 31             3.20              217262
# 32             3.40              124085

# %%
summary_df = summarize_character(df)
df_characters_heroes = pd.concat([df_characters_heroes, summary_df], ignore_index=True)

# %% [markdown]
# #### 3.4 Harry Potter

# %%
df=search_by_character_and_movies("harry potter", "harry potter")
df
# Out:
#    movieId         characters         actor_name  \
# 0     5816       Harry Potter   Daniel Radcliffe
# 1    81834       Harry Potter   Daniel Radcliffe
# 2    88125       Harry Potter   Daniel Radcliffe
# 3    40815       Harry Potter   Daniel Radcliffe
# 4    69844       Harry Potter   Daniel Radcliffe
# 5    54001       Harry Potter   Daniel Radcliffe
# 6     8368       Harry Potter   Daniel Radcliffe
# 7     4896       Harry Potter   Daniel Radcliffe
# 8     4896  Baby Harry Potter  Saunders Triplets
#
#                                          movie_title  ml_avg_rating  \
# 0     Harry Potter and the Chamber of Secrets (2002)           3.65
# 1  Harry Potter and the Deathly Hallows: Part 1 (...           3.84
# 2  Harry Potter and the Deathly Hallows: Part 2 (...           3.90
# 3         Harry Potter and the Goblet of Fire (2005)           3.77
# 4      Harry Potter and the Half-Blood Prince (2009)           3.83
# 5   Harry Potter and the Order of the Phoenix (2007)           3.76
# 6    Harry Potter and the Prisoner of Azkaban (2004)           3.82
# 7  Harry Potter and the Sorcerer's Stone (a.k.a. ...           3.70
# 8  Harry Potter and the Sorcerer's Stone (a.k.a. ...           3.70
#
#    ml_ratings_count  imdb_avg_rating  imdb_ratings_count
# 0             31004             3.75              746380
# 1             21781             3.85              646233
# 2             20837             4.05             1019944
# 3             27128             3.85              733319
# 4             21849             3.80              642414
# 5             21900             3.75              681723
# 6             32517             3.95              746697
# 7             36127             3.85              924808
# 8             36127             3.85              924808

# %%
summary_df = summarize_character(df)
df_characters_heroes = pd.concat([df_characters_heroes, summary_df], ignore_index=True)

# %% [markdown]
# #### 3.5 Frodo from the Lord of the Rings

# %%
df= search_by_character_and_actor("Frodo","Elijah Wood")
df
# Out:
#    movieId characters   actor_name  \
# 0     4993      Frodo  Elijah Wood
# 1     7153      Frodo  Elijah Wood
# 2     5952      Frodo  Elijah Wood
#
#                                          movie_title  ml_avg_rating  \
# 0  Lord of the Rings: The Fellowship of the Ring,...           4.10
# 1  Lord of the Rings: The Return of the King, The...           4.11
# 2      Lord of the Rings: The Two Towers, The (2002)           4.08
#
#    ml_ratings_count  imdb_avg_rating  imdb_ratings_count
# 0             79940             4.45             2152498
# 1             75512             4.50             2117156
# 2             73687             4.40             1910440

# %%
summary_df = summarize_character(df)
df_characters_heroes = pd.concat([df_characters_heroes, summary_df], ignore_index=True)

# %% [markdown]
# #### 3.6 Ellen Ripley from Alien

# %%
df= search_by_character_and_actor("Ripley","Sigourney Weaver")
df
# Out:
#    movieId characters        actor_name                     movie_title  \
# 0     1214     Ripley  Sigourney Weaver                    Alien (1979)
# 1     1690     Ripley  Sigourney Weaver      Alien: Resurrection (1997)
# 2     1200     Ripley  Sigourney Weaver                   Aliens (1986)
# 3     1320     Ripley  Sigourney Weaver  Alien³ (a.k.a. Alien 3) (1992)
#
#    ml_avg_rating  ml_ratings_count  imdb_avg_rating  imdb_ratings_count
# 0           4.07             46572             4.25             1040401
# 1           3.04             14811             3.10              287853
# 2           4.01             40182             4.20              824656
# 3           3.12             17653             3.20              347338

# %%
summary_df = summarize_character(df)
df_characters_heroes = pd.concat([df_characters_heroes, summary_df], ignore_index=True)

# %% [markdown]
# #### 3.7 John Mcclane from Die Hard

# %%
df= search_by_character("John McClane")
df
# Out:
#    movieId    characters     actor_name                        movie_title  \
# 0    80183  John McClane  Matthew Géczy              8th Wonderland (2008)
# 1     1036  John McClane   Bruce Willis                    Die Hard (1988)
# 2     1370  John McClane   Bruce Willis                  Die Hard 2 (1990)
# 3      165  John McClane   Bruce Willis  Die Hard: With a Vengeance (1995)
# 4   100498  John McClane   Bruce Willis     Good Day to Die Hard, A (2013)
# 5    53972  John McClane   Bruce Willis       Live Free or Die Hard (2007)
#
#    ml_avg_rating  ml_ratings_count  imdb_avg_rating  imdb_ratings_count
# 0           3.19                 8             3.05                 522
# 1           3.94             47472             4.10             1005560
# 2           3.46             20122             3.60              400971
# 3           3.52             43336             3.80              425108
# 4           2.55              1571             2.60              221078
# 5           3.43              8784             3.55              432223

# %%
summary_df = summarize_character(df)
df_characters_heroes = pd.concat([df_characters_heroes, summary_df], ignore_index=True)

# %% [markdown]
# #### 3.8 Neo from Matrix

# %%
df= search_by_character_and_actor("Neo","Keanu Reeves")
df
# Out:
#    movieId characters    actor_name                     movie_title  \
# 0     6365        Neo  Keanu Reeves     Matrix Reloaded, The (2003)
# 1     6934        Neo  Keanu Reeves  Matrix Revolutions, The (2003)
# 2     2571        Neo  Keanu Reeves              Matrix, The (1999)
#
#    ml_avg_rating  ml_ratings_count  imdb_avg_rating  imdb_ratings_count
# 0           3.38             30788             3.60              660874
# 1           3.24             24470             3.35              568043
# 2           4.16            107056             4.35             2198642

# %%
summary_df = summarize_character(df)
df_characters_heroes = pd.concat([df_characters_heroes, summary_df], ignore_index=True)

# %% [markdown]
# ### 4 Bigest Villains Ever
# #### 4.1 Darth Vader

# %%
df= search_by_character_and_movies("darth vader","Star Wars")
df
# Out:
#     movieId   characters        actor_name  \
# 0    261153  Darth Vader        Matt Sloan
# 1    261155  Darth Vader       Phil LaMarr
# 2    136485  Darth Vader   Abraham Benrubi
# 3    181355  Darth Vader   Abraham Benrubi
# 4    181357  Darth Vader   Abraham Benrubi
# 5       260  Darth Vader      David Prowse
# 6      1196  Darth Vader      David Prowse
# 7      1210  Darth Vader  James Earl Jones
# 8    229523  Darth Vader        Jack Foley
# 9    229523  Darth Vader      Kevin Zabawa
# 10   135216  Darth Vader  James Earl Jones
#
#                                           movie_title  ml_avg_rating  \
# 0       LEGO Star Wars: The Empire Strikes Out (2012)           1.13
# 1           LEGO Star Wars: The Padawan Menace (2011)           2.31
# 2                     Robot Chicken: Star Wars (2007)           3.48
# 3          Robot Chicken: Star Wars Episode II (2008)           3.37
# 4         Robot Chicken: Star Wars Episode III (2010)           3.60
# 5           Star Wars: Episode IV - A New Hope (1977)           4.09
# 6   Star Wars: Episode V - The Empire Strikes Back...           4.12
# 7   Star Wars: Episode VI - Return of the Jedi (1983)           3.98
# 8                              Star Wars: Revelations           2.00
# 9                              Star Wars: Revelations           2.00
# 10               The Star Wars Holiday Special (1978)           1.40
#
#     ml_ratings_count  imdb_avg_rating  imdb_ratings_count
# 0                  8             3.55                1736
# 1                  8             3.50                2276
# 2                290             4.00                8864
# 3                 68             4.00                5211
# 4                 97             4.00                4921
# 5              97202             4.30             1538496
# 6              80200             4.35             1472190
# 7              76773             4.15             1186668
# 8                  4             2.50                1207
# 9                  4             2.50                1207
# 10               248             1.10               18052

# %%
df_characters_vilains = summarize_character(df)

# %% [markdown]
# #### 4.2 Hannibal Lecter

# %%
df= search_by_character_and_actor("lecter","Anthony Hopkins")
df
# Out:
#    movieId           characters       actor_name  \
# 0     4148      Hannibal Lecter  Anthony Hopkins
# 1     5630      Hannibal Lecter  Anthony Hopkins
# 2      593  Dr. Hannibal Lecter  Anthony Hopkins
#
#                         movie_title  ml_avg_rating  ml_ratings_count  \
# 0                   Hannibal (2001)           3.24             12067
# 1                 Red Dragon (2002)           3.56              9272
# 2  Silence of the Lambs, The (1991)           4.15            101802
#
#    imdb_avg_rating  imdb_ratings_count
# 0              3.4              309421
# 1              3.6              307464
# 2              4.3             1675121

# %%
summary_df = summarize_character(df)
df_characters_vilains = pd.concat([df_characters_vilains, summary_df], ignore_index=True)

# %% [markdown]
# #### 4.3 Joker

# %%
df1= search_by_character_and_movies("joker","batman")
df2= search_by_character_and_actor("joker","Heath Ledger")

df = pd.concat([df1, df2], ignore_index=True)
df
# Out:
#     movieId characters                actor_name  \
# 0     26152  The Joker              Cesar Romero
# 1       592      Joker            Jack Nicholson
# 2    186985  The Joker             Wataru Takagi
# 3    140115  The Joker                Troy Baker
# 4    202099      Joker                Troy Baker
# 5    178997      Joker              Jeff Bergman
# 6    182613  The Joker             Andrew Koenig
# 7    165085  The Joker              Jeff Bergman
# 8    161354  The Joker               Mark Hamill
# 9    165153      Joker             John DiMaggio
# 10   183455  The Joker              Jeff Bennett
# 11   118173  The Joker  Kevin Michael Richardson
# 12   167746      Joker         Zach Galifianakis
# 13    58559      Joker              Heath Ledger
#
#                                           movie_title  ml_avg_rating  \
# 0                                       Batman (1966)           3.21
# 1                                       Batman (1989)           3.39
# 2                                 Batman Ninja (2018)           2.96
# 3             Batman Unlimited: Monster Mayhem (2015)           2.09
# 4      Batman vs. Teenage Mutant Ninja Turtles (2019)           3.38
# 5                          Batman vs. Two-Face (2017)           2.66
# 6                             Batman: Dead End (2003)           3.09
# 7        Batman: Return of the Caped Crusaders (2016)           2.88
# 8                     Batman: The Killing Joke (2016)           3.00
# 9   LEGO DC Comics Super Heroes: Batman: Be-League...           2.63
# 10  Scooby-Doo! & Batman: The Brave and the Bold (...           2.76
# 11                      The Batman vs. Dracula (2005)           2.96
# 12                       The Lego Batman Movie (2017)           3.58
# 13                            Dark Knight, The (2008)           4.19
#
#     ml_ratings_count  imdb_avg_rating  imdb_ratings_count
# 0               1092             3.25               37499
# 1              56330             3.75              426194
# 2                199             2.80               23774
# 3                 40             2.80                3347
# 4                 85             3.55               13701
# 5                 53             3.10                4929
# 6                 23             3.60                6367
# 7                 76             3.35                6869
# 8                524             3.20               64721
# 9                 15             3.20                1777
# 10                25             3.25                3681
# 11                79             3.30               12199
# 12              2294             3.65              187623
# 13             65349             4.55             3092751

# %%
summary_df = summarize_character(df)
df_characters_vilains = pd.concat([df_characters_vilains, summary_df], ignore_index=True)

# %% [markdown]
# #### 4.4 Norman Bates

# %%
df= search_by_character("norman bates")
df
# Out:
#    movieId             characters       actor_name  \
# 0   202171           Norman Bates        Kurt Paul
# 1     1219           Norman Bates  Anthony Perkins
# 2     2389           Norman Bates     Vince Vaughn
# 3     2902           Norman Bates  Anthony Perkins
# 4     2903           Norman Bates  Anthony Perkins
# 5   184071           Norman Bates  Anthony Perkins
# 6   211966  madre de Norman Bates   Silvia Gambino
# 7   161014           Norman Bates   Scott McGinnis
#
#                        movie_title  ml_avg_rating  ml_ratings_count  \
# 0               Bates Motel (1987)           2.28                 9
# 1                    Psycho (1960)           4.06             28016
# 2                    Psycho (1998)           2.81              3704
# 3                 Psycho II (1983)           2.59              1342
# 4                Psycho III (1986)           2.13               858
# 5  Psycho IV: The Beginning (1990)           2.52                29
# 6         WHAT DID JACK DO? (2017)           3.28               130
# 7                     Wacko (1982)           2.61                 9
#
#    imdb_avg_rating  imdb_ratings_count
# 0             1.90                2007
# 1             4.25              769531
# 2             2.30               52328
# 3             3.30               34265
# 4             2.75               17997
# 5             2.70               10723
# 6              NaN                <NA>
# 7             2.45                1600

# %%
summary_df = summarize_character(df)
df_characters_vilains = pd.concat([df_characters_vilains, summary_df], ignore_index=True)

# %% [markdown]
# #### 4.5 Chucky

# %%
df= search_by_character_and_actor("Chucky","Brad Dourif")
df
# Out:
#    movieId characters   actor_name                              movie_title  \
# 0     2315     Chucky  Brad Dourif  Bride of Chucky (Child's Play 4) (1998)
# 1     1991     Chucky  Brad Dourif                      Child's Play (1988)
# 2     1992     Chucky  Brad Dourif                    Child's Play 2 (1990)
# 3     1993     Chucky  Brad Dourif                    Child's Play 3 (1991)
# 4   178447     Chucky  Brad Dourif                    Cult of Chucky (2017)
# 5     8967     Chucky  Brad Dourif   Seed of Chucky (Child's Play 5) (2004)
#
#    ml_avg_rating  ml_ratings_count  imdb_avg_rating  imdb_ratings_count
# 0           2.21              2359             2.80               69094
# 1           2.87              3464             3.35              128788
# 2           2.37              1562             3.00               63013
# 3           2.11              1249             2.60               50271
# 4           2.57               157             2.65               33243
# 5           2.24               626             2.45               53532

# %%
summary_df = summarize_character(df)
df_characters_vilains = pd.concat([df_characters_vilains, summary_df], ignore_index=True)

# %% [markdown]
# #### 4.6 Cruella de De vil

# %%
df= search_by_character("Cruella")
df
# Out:
#    movieId      characters         actor_name  \
# 0     1367   Cruella DeVil        Glenn Close
# 1     2085  Cruella De Vil   Betty Lou Gerson
# 2   121099         Cruella  Susanne Blakeslee
# 3     3991  Cruella de Vil        Glenn Close
# 4   249540         Cruella         Emma Stone
# 5   174535  Cruella De Vil  Susanne Blakeslee
#
#                                          movie_title  ml_avg_rating  \
# 0                              101 Dalmatians (1996)           3.05
# 1  101 Dalmatians (One Hundred and One Dalmatians...           3.43
# 2  101 Dalmatians II: Patch's London Adventure (2...           2.87
# 3                              102 Dalmatians (2000)           2.38
# 4                                     Cruella (2021)           3.50
# 5                  Mickey's House of Villains (2001)           2.64
#
#    ml_ratings_count  imdb_avg_rating  imdb_ratings_count
# 0             11168             2.90              122696
# 1             10747             3.65              192916
# 2               129             2.85               11760
# 3              2288             2.45               41319
# 4               990             3.65              288493
# 5                33             3.30                4526

# %%
summary_df = summarize_character(df)
df_characters_vilains = pd.concat([df_characters_vilains, summary_df], ignore_index=True)

# %% [markdown]
# #### 4.7 Michael Corleone from the Godfather

# %%
df= search_by_character_and_actor("michael","pacino")
df
# Out:
#    movieId        characters actor_name                      movie_title  \
# 0      858           Michael  Al Pacino            Godfather, The (1972)
# 1     1221           Michael  Al Pacino   Godfather: Part II, The (1974)
# 2     2023  Michael Corleone  Al Pacino  Godfather: Part III, The (1990)
#
#    ml_avg_rating  ml_ratings_count  imdb_avg_rating  imdb_ratings_count
# 0           4.33             75004              4.6             2173294
# 1           4.27             47271              4.5             1460084
# 2           3.45             14446              3.8              446783

# %%
summary_df = summarize_character(df,"Michael Corleone")
df_characters_vilains = pd.concat([df_characters_vilains, summary_df], ignore_index=True)

# %% [markdown]
# #### 4.8 Loki da serie Thor

# %%
df= search_by_character_and_actor("loki","Tom Hiddleston")
df
# Out:
#    movieId characters      actor_name                  movie_title  \
# 0    89745       Loki  Tom Hiddleston         Avengers, The (2012)
# 1    86332       Loki  Tom Hiddleston                  Thor (2011)
# 2   122916       Loki  Tom Hiddleston        Thor: Ragnarok (2017)
# 3   106072       Loki  Tom Hiddleston  Thor: The Dark World (2013)
#
#    ml_avg_rating  ml_ratings_count  imdb_avg_rating  imdb_ratings_count
# 0           3.74             27495             4.00             1532467
# 1           3.32             14900             3.50              949663
# 2           3.90             14231             3.95              875233
# 3           3.19              8374             3.35              764561

# %%
summary_df = summarize_character(df)
df_characters_vilains = pd.concat([df_characters_vilains, summary_df], ignore_index=True)

# %% [markdown]
# ### 5 Competitions
# #### 5.1 Summary of characteres in competition
# ##### 5.1.1 Heroes

# %%
df_characters_heroes
# Out:
#       character  movies_count  character_avg_rating  character_rating_count  \
# 0        Batman            32              3.288466                  184975
# 1      Superman            17              2.980822                   50456
# 2    James Bond            31              3.485162                  233408
# 3  Harry Potter             8              3.762671                  249270
# 4         Frodo             3              4.096864                  229139
# 5        Ripley             4              3.781146                  119218
# 6  John McClane             6              3.655324                  121293
# 7           Neo             3              3.873352                  162314
#
#    character_imdb_rating  character_imdb_count
# 0               3.611069               5268974
# 1               3.177807               1601806
# 2               3.520098               6128971
# 3               3.864679               7066326
# 4               4.451672               6180094
# 5               3.955242               2500248
# 6               3.738737               2485462
# 7               4.039663               3427559

# %% [markdown]
# #### 5.1.2 Vilains

# %%
df_characters_vilains
# Out:
#           character  movies_count  character_avg_rating  \
# 0       Darth Vader            10              4.062404
# 1   Hannibal Lecter             3              4.016402
# 2         The Joker            14              3.802336
# 3      Norman Bates             8              3.812652
# 4            Chucky             6              2.474050
# 5     Cruella DeVil             6              3.166728
# 6  Michael Corleone             3              4.216274
# 7              Loki             4              3.607896
#
#    character_rating_count  character_imdb_rating  character_imdb_count
# 0                  254902               4.258658               4240828
# 1                  123141               4.084598               2292006
# 2                  126184               4.356721               3885432
# 3                   34097               4.040868                888451
# 4                    9417               2.924790                397941
# 5                   25355               3.419390                661710
# 6                  136721               4.476614               4080161
# 7                   65000               3.753620               4121924

# %% [markdown]
# ### 5.2 Auxiliary functions to deal with the "competition"

# %%
# ---- Helper functions for scores ----

def total_ratings(row):
    """Total number of ratings (MovieLens + IMDb)."""
    return row["character_rating_count"] + row["character_imdb_count"]

def weighted_global_rating(row):
    """Weighted average of MovieLens and IMDb ratings."""
    ml_count = row["character_rating_count"]
    imdb_count = row["character_imdb_count"]
    ml_rating = row["character_avg_rating"]
    imdb_rating = row["character_imdb_rating"]
    
    total_count = ml_count + imdb_count
    if total_count == 0:
        return 0.0
    return (ml_rating * ml_count + imdb_rating * imdb_count) / total_count

def product_score(row):
    """Score based on rating * count for both MovieLens and IMDb."""
    ml_part = row["character_avg_rating"] * row["character_rating_count"]
    imdb_part = row["character_imdb_rating"] * row["character_imdb_count"]
    return ml_part + imdb_part


# ---- Function to play one knockout round ----

def play_round(df, score_func, round_name="Round", random_state=42, side_label=""):
    """
    Play a knockout round:
        - Shuffle contestants
        - Pair them 1 vs 1
        - Winner decided by score_func(row)
    Returns:
        winners_df, matches (list of dicts with match results)
    """
    # Shuffle to randomize matchups
    shuffled = df.sample(frac=1, random_state=random_state).reset_index(drop=True)
    
    winners = []
    matches = []

    # We assume an even number of rows (8, 4, 2, etc.)
    for i in range(0, len(shuffled), 2):
        p1 = shuffled.iloc[i]
        p2 = shuffled.iloc[i + 1]
        
        s1 = score_func(p1)
        s2 = score_func(p2)
        
        # Decide winner (tie goes to p1)
        winner = p1 if s1 >= s2 else p2
        
        matches.append({
            "round": round_name,
            "side": side_label,
            "character_1": p1["character"],
            "score_1": s1,
            "character_2": p2["character"],
            "score_2": s2,
            "winner": winner["character"],
        })
        
        winners.append(winner)

    winners_df = pd.DataFrame(winners).reset_index(drop=True)
    return winners_df, matches


# ---- Main tournament function ----

def run_tournament(df_characters_heroes, df_characters_vilains, base_seed=42):
    """
    Run the heroes vs villains tournament.
    
    Input:
        df_characters_heroes  - dataframe with 8 heroes
        df_characters_vilains - dataframe with 8 villains
        
    Returns:
        results: dict with
            - "matches": list of all match dicts
            - "hero_champion": row (Series) of hero champion
            - "villain_champion": row (Series) of villain champion
            - "grand_final": dict with final match info
    """
    all_matches = []
    
    # ---------- HEROES BRACKET ----------
    # Round 1: 8 -> 4 (by total ratings)
    heroes_r1_winners, matches = play_round(
        df_characters_heroes,
        score_func=total_ratings,
        round_name="Heroes R1 (total ratings)",
        random_state=base_seed,
        side_label="heroes"
    )
    all_matches.extend(matches)
    
    # Round 2: 4 -> 2 (by weighted global rating)
    heroes_r2_winners, matches = play_round(
        heroes_r1_winners,
        score_func=weighted_global_rating,
        round_name="Heroes R2 (weighted rating)",
        random_state=base_seed + 1,
        side_label="heroes"
    )
    all_matches.extend(matches)
    
    # Round 3: 2 -> 1 champion (by product score)
    heroes_champion_df, matches = play_round(
        heroes_r2_winners,
        score_func=product_score,
        round_name="Heroes Final (product score)",
        random_state=base_seed + 2,
        side_label="heroes"
    )
    all_matches.extend(matches)
    hero_champion = heroes_champion_df.iloc[0]
    
    # ---------- VILLAINS BRACKET ----------
    villains_r1_winners, matches = play_round(
        df_characters_vilains,
        score_func=total_ratings,
        round_name="Villains R1 (total ratings)",
        random_state=base_seed,
        side_label="villains"
    )
    all_matches.extend(matches)
    
    villains_r2_winners, matches = play_round(
        villains_r1_winners,
        score_func=weighted_global_rating,
        round_name="Villains R2 (weighted rating)",
        random_state=base_seed + 1,
        side_label="villains"
    )
    all_matches.extend(matches)
    
    villains_champion_df, matches = play_round(
        villains_r2_winners,
        score_func=product_score,
        round_name="Villains Final (product score)",
        random_state=base_seed + 2,
        side_label="villains"
    )
    all_matches.extend(matches)
    villain_champion = villains_champion_df.iloc[0]
    
    # ---------- GRAND FINAL ----------
    # Hero champion vs Villain champion using product_score again
    grand_final_contestants = pd.DataFrame([hero_champion, villain_champion]).reset_index(drop=True)
    gf_winners_df, gf_matches = play_round(
        grand_final_contestants,
        score_func=product_score,
        round_name="Grand Final (Hero vs Villain)",
        random_state=base_seed + 3,
        side_label="grand_final"
    )
    all_matches.extend(gf_matches)
    
    grand_final = gf_matches[0]  # only one match
    grand_champion = gf_winners_df.iloc[0]
    
    results = {
        "matches": all_matches,
        "hero_champion": hero_champion,
        "villain_champion": villain_champion,
        "grand_final": grand_final,
        "grand_champion": grand_champion,
    }
    
    return results

# %% [markdown]
# ### 5.3 Figth!
#
# In this chapter the competition is triggerd by the lauch of the of the sub "run_tournament"

# %%
results = run_tournament(df_characters_heroes, df_characters_vilains, base_seed=42)

# %% [markdown]
# ### 5.4 Competiton results

# %% [markdown]
# #### 5.4.1 All rounds

# %%
# All matches as a DataFrame
matches_df = pd.DataFrame(results["matches"])
matches_df
# Out:
#                              round         side       character_1  \
# 0        Heroes R1 (total ratings)       heroes          Superman
# 1        Heroes R1 (total ratings)       heroes            Batman
# 2        Heroes R1 (total ratings)       heroes        James Bond
# 3        Heroes R1 (total ratings)       heroes      Harry Potter
# 4      Heroes R2 (weighted rating)       heroes             Frodo
# 5      Heroes R2 (weighted rating)       heroes      Harry Potter
# 6     Heroes Final (product score)       heroes            Ripley
# 7      Villains R1 (total ratings)     villains   Hannibal Lecter
# 8      Villains R1 (total ratings)     villains       Darth Vader
# 9      Villains R1 (total ratings)     villains         The Joker
# 10     Villains R1 (total ratings)     villains      Norman Bates
# 11   Villains R2 (weighted rating)     villains         The Joker
# 12   Villains R2 (weighted rating)     villains  Michael Corleone
# 13  Villains Final (product score)     villains  Michael Corleone
# 14   Grand Final (Hero vs Villain)  grand_final             Frodo
#
#          score_1       character_2       score_2            winner
# 0   1.652262e+06            Ripley  2.619466e+06            Ripley
# 1   5.453949e+06               Neo  3.589873e+06            Batman
# 2   6.362379e+06             Frodo  6.409233e+06             Frodo
# 3   7.315596e+06      John McClane  2.606755e+06      Harry Potter
# 4   4.438988e+00            Batman  3.600127e+00             Frodo
# 5   3.861203e+00            Ripley  3.947318e+00            Ripley
# 6   1.033987e+07             Frodo  2.845051e+07             Frodo
# 7   2.415147e+06     Cruella DeVil  6.870650e+05   Hannibal Lecter
# 8   4.495730e+06              Loki  4.186924e+06       Darth Vader
# 9   4.011616e+06            Chucky  4.073580e+05         The Joker
# 10  9.225480e+05  Michael Corleone  4.216882e+06  Michael Corleone
# 11  4.339283e+00       Darth Vader  4.247531e+00         The Joker
# 12  4.468173e+00   Hannibal Lecter  4.081120e+00  Michael Corleone
# 13  1.884176e+07         The Joker  1.740754e+07  Michael Corleone
# 14  2.845051e+07  Michael Corleone  1.884176e+07             Frodo

# %% [markdown]
# #### 5.4.2 Results of the hero champion

# %%
# Campeão dos heróis
results["hero_champion"]
# Out:
# character                    Frodo
# movies_count                     3
# character_avg_rating      4.096864
# character_rating_count      229139
# character_imdb_rating     4.451672
# character_imdb_count       6180094
# Name: 0, dtype: object

# %% [markdown]
# #### 5.4.3 Results of the Vilain Champion

# %%
# Campeão dos vilões
results["villain_champion"]
# Out:
# character                 Michael Corleone
# movies_count                             3
# character_avg_rating              4.216274
# character_rating_count              136721
# character_imdb_rating             4.476614
# character_imdb_count               4080161
# Name: 0, dtype: object

# %% [markdown]
# #### 5.4.4 Grand Finale

# %%
# Finalíssima (detalhe do combate final)
results["grand_final"]
# Out:
# {'round': 'Grand Final (Hero vs Villain)',
#  'side': 'grand_final',
#  'character_1': 'Frodo',
#  'score_1': np.float64(28450505.380000006),
#  'character_2': 'Michael Corleone',
#  'score_2': np.float64(18841758.99),
#  'winner': 'Frodo'}

# %% [markdown]
# #### 5.4.5 Final result

# %%
# Grande campeão absoluto
results["grand_champion"]
# Out:
# character                    Frodo
# movies_count                     3
# character_avg_rating      4.096864
# character_rating_count      229139
# character_imdb_rating     4.451672
# character_imdb_count       6180094
# Name: 0, dtype: object

# %% [markdown]
# ### 6 Other interesting queries
# #### 6.1 Best ranked Writers (with minimium 100000 ratings)

# %%
query_top50_writers = """
WITH joined AS (
    SELECT
        w.writer_name,
        r.movieId,
        r.rating
    FROM ratings r
    JOIN movielens_writers w
        ON w.movieId = r.movieId
    WHERE w.writer_name IS NOT NULL
),
writer_stats AS (
    SELECT
        writer_name,
        COUNT(*) AS total_ratings,
        COUNT(DISTINCT movieId) AS total_movies,
        ROUND(AVG(rating), 2) AS avg_rating
    FROM joined
    GROUP BY writer_name
    HAVING COUNT(*) >= 100000
),
writer_movie_ratings AS (
    SELECT
        writer_name,
        movieId,
        COUNT(*) AS movie_ratings
    FROM joined
    GROUP BY writer_name, movieId
),
best_movie_per_writer AS (
    SELECT
        writer_name,
        movieId,
        movie_ratings,
        ROW_NUMBER() OVER (
            PARTITION BY writer_name
            ORDER BY movie_ratings DESC, movieId
        ) AS rn
    FROM writer_movie_ratings
)
SELECT
    ws.writer_name,
    ws.total_ratings,
    ws.total_movies,
    ws.avg_rating,
    m.movieId          AS top_movie_id,
    m.title            AS top_movie_title,
    bm.movie_ratings   AS top_movie_ratings
FROM writer_stats ws
JOIN best_movie_per_writer bm
    ON ws.writer_name = bm.writer_name
   AND bm.rn = 1
JOIN movies m
    ON m.movieId = bm.movieId
ORDER BY
    ws.avg_rating DESC,
    ws.total_ratings DESC
LIMIT 50;
"""

df_top50_writers = con.sql(query_top50_writers).df()
df_top50_writers
# Out:
#            writer_name  total_ratings  total_movies  avg_rating  top_movie_id  \
# 0       Hayao Miyazaki         111224            12        4.14          5618
# 1       Jonathan Nolan         171702             4        4.13         58559
# 2    Christopher Nolan         136039             5        4.11         79132
# 3       J.R.R. Tolkien         229152             5        4.10          4993
# 4        Winston Groom         113581             1        4.07           356
# 5           Ethan Coen         131356             6        4.00           608
# 6        Thomas Harris         127438             6        4.00           593
# 7      Stanley Kubrick         177405            10        3.96          1206
# 8    Quentin Tarantino         396857            13        3.95           296
# 9         Stephen King         332400            60        3.92           318
# 10     Lawrence Kasdan         199547            11        3.92          1210
# 11         Pete Docter         114886             5        3.90          4886
# 12     Lilly Wachowski         220221             9        3.83          2571
# 13       Andrew Niccol         113340             9        3.76          1682
# 14       John Lasseter         178856            15        3.75             1
# 15       James Cameron         335931            10        3.73           589
# 16          Luc Besson         158164            41        3.72           293
# 17         Woody Allen         145974            54        3.72          1230
# 18     Robert Zemeckis         128431            11        3.72          1270
# 19        J.K. Rowling         110495             6        3.70          4896
# 20  M. Night Shyamalan         125316            12        3.63          2762
# 21        George Lucas         215720            14        3.62           260
# 22         Ted Elliott         101429             6        3.59          6539
# 23         John Hughes         197367            29        3.44           586
# 24    Gene Roddenberry         153729            16        3.37           329
# 25    Michael Crichton         217371            19        3.30           480
# 26         Dean Devlin         113812             4        3.30           780
# 27  Jonathan Hensleigh         106629             8        3.30           165
# 28            Bob Kane         176910            12        3.25           592
#
#                                       top_movie_title  top_movie_ratings
# 0   Spirited Away (Sen to Chihiro no kamikakushi) ...              35375
# 1                             Dark Knight, The (2008)              65349
# 2                                    Inception (2010)              65056
# 3   Lord of the Rings: The Fellowship of the Ring,...              79940
# 4                                 Forrest Gump (1994)             113581
# 5                                        Fargo (1996)              61977
# 6                    Silence of the Lambs, The (1991)             101802
# 7                          Clockwork Orange, A (1971)              38195
# 8                                 Pulp Fiction (1994)             108756
# 9                    Shawshank Redemption, The (1994)             122296
# 10  Star Wars: Episode VI - Return of the Jedi (1983)              76773
# 11                              Monsters, Inc. (2001)              48441
# 12                                 Matrix, The (1999)             107056
# 13                            Truman Show, The (1998)              45809
# 14                                   Toy Story (1995)              76813
# 15                  Terminator 2: Judgment Day (1991)              71820
# 16  Léon: The Professional (a.k.a. The Professiona...              43539
# 17                                  Annie Hall (1977)              21245
# 18                          Back to the Future (1985)              67777
# 19  Harry Potter and the Sorcerer's Stone (a.k.a. ...              36127
# 20                            Sixth Sense, The (1999)              60439
# 21          Star Wars: Episode IV - A New Hope (1977)              97202
# 22  Pirates of the Caribbean: The Curse of the Bla...              50868
# 23                                  Home Alone (1990)              35843
# 24                      Star Trek: Generations (1994)              30854
# 25                               Jurassic Park (1993)              83026
# 26               Independence Day (a.k.a. ID4) (1996)              63687
# 27                  Die Hard: With a Vengeance (1995)              43336
# 28                                      Batman (1989)              56330

# %% [markdown]
# #### 6.2 Best ranked Directors (with minimium 200000 ratings)

# %%
query_top50_directors = """
WITH joined AS (
    SELECT
        d.director_name,
        r.movieId,
        r.rating
    FROM ratings r
    JOIN movielens_directors d
        ON d.movieId = r.movieId
    WHERE d.director_name IS NOT NULL
),
director_stats AS (
    SELECT
        director_name,
        COUNT(*) AS total_ratings,
        COUNT(DISTINCT movieId) AS total_movies,
        ROUND(AVG(rating), 2) AS avg_rating
    FROM joined
    GROUP BY director_name
    HAVING COUNT(*) >= 200000
),
director_movie_ratings AS (
    SELECT
        director_name,
        movieId,
        COUNT(*) AS movie_ratings
    FROM joined
    GROUP BY director_name, movieId
),
best_movie_per_director AS (
    SELECT
        director_name,
        movieId,
        movie_ratings,
        ROW_NUMBER() OVER (
            PARTITION BY director_name
            ORDER BY movie_ratings DESC, movieId
        ) AS rn
    FROM director_movie_ratings
)
SELECT
    ds.director_name,
    ds.total_ratings,
    ds.total_movies,
    ds.avg_rating,
    m.movieId        AS top_movie_id,
    m.title          AS top_movie_title,
    bm.movie_ratings AS top_movie_ratings
FROM director_stats ds
JOIN best_movie_per_director bm
    ON ds.director_name = bm.director_name
   AND bm.rn = 1
JOIN movies m
    ON m.movieId = bm.movieId
ORDER BY
    ds.avg_rating DESC,
    ds.total_ratings DESC
LIMIT 50;
"""

df_top50_directors = con.sql(query_top50_directors).df()
df_top50_directors
# Out:
#            director_name  total_ratings  total_movies  avg_rating  \
# 0      Christopher Nolan         360868            11        4.08
# 1   Francis Ford Coppola         212138            22        4.05
# 2      Quentin Tarantino         350473            12        4.01
# 3        Stanley Kubrick         228429            16        3.97
# 4          Peter Jackson         303438            14        3.95
# 5          David Fincher         290069            10        3.94
# 6        Martin Scorsese         294606            41        3.93
# 7           Ridley Scott         297279            28        3.82
# 8       Steven Spielberg         702204            35        3.81
# 9        Robert Zemeckis         373858            22        3.76
# 10         James Cameron         323491            12        3.74
# 11          George Lucas         203459             8        3.63
# 12            Ron Howard         247359            32        3.58
# 13            Tim Burton         285348            24        3.39
#
#     top_movie_id                                    top_movie_title  \
# 0          58559                            Dark Knight, The (2008)
# 1            858                              Godfather, The (1972)
# 2            296                                Pulp Fiction (1994)
# 3           1258                                Shining, The (1980)
# 4           4993  Lord of the Rings: The Fellowship of the Ring,...
# 5           2959                                  Fight Club (1999)
# 6           1213                                  Goodfellas (1990)
# 7           3578                                   Gladiator (2000)
# 8            527                            Schindler's List (1993)
# 9            356                                Forrest Gump (1994)
# 10           589                  Terminator 2: Judgment Day (1991)
# 11           260          Star Wars: Episode IV - A New Hope (1977)
# 12           150                                   Apollo 13 (1995)
# 13           592                                      Batman (1989)
#
#     top_movie_ratings
# 0               65349
# 1               75004
# 2              108756
# 3               40297
# 4               79940
# 5               86207
# 6               44592
# 7               60749
# 8               84232
# 9              113581
# 10              71820
# 11              97202
# 12              62521
# 13              56330

# %% [markdown]
# #### 6.2 Best ranked Producers (with minimium 200000 ratings)

# %%
query_top50_producers_best_ranked = """
WITH joined AS (
    SELECT
        p.producer_name,
        r.movieId,
        r.rating
    FROM ratings r
    JOIN movielens_main_producers p
        ON p.movieId = r.movieId
    WHERE p.producer_name IS NOT NULL
),
producer_stats AS (
    SELECT
        producer_name,
        COUNT(*) AS total_ratings,
        COUNT(DISTINCT movieId) AS total_movies,
        ROUND(AVG(rating), 2) AS avg_rating
    FROM joined
    GROUP BY producer_name
    HAVING COUNT(*) >= 200000
),
producer_movie_ratings AS (
    SELECT
        producer_name,
        movieId,
        COUNT(*) AS movie_ratings
    FROM joined
    GROUP BY producer_name, movieId
),
best_movie_per_producer AS (
    SELECT
        producer_name,
        movieId,
        movie_ratings,
        ROW_NUMBER() OVER (
            PARTITION BY producer_name
            ORDER BY movie_ratings DESC, movieId
        ) AS rn
    FROM producer_movie_ratings
)
SELECT
    ps.producer_name,
    ps.total_ratings,
    ps.total_movies,
    ps.avg_rating,
    m.movieId AS top_movie_id,
    m.title   AS top_movie_title,
    bm.movie_ratings AS top_movie_ratings
FROM producer_stats ps
JOIN best_movie_per_producer bm
    ON ps.producer_name = bm.producer_name
   AND bm.rn = 1
JOIN movies m
    ON m.movieId = bm.movieId
ORDER BY
    ps.avg_rating DESC,
    ps.total_ratings DESC
LIMIT 50;
"""

df_top50_producers_best_ranked = con.sql(query_top50_producers_best_ranked).df()
df_top50_producers_best_ranked
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#            producer_name  total_ratings  total_movies  avg_rating  \
# 0      Christopher Nolan         259578            10        4.09
# 1            Emma Thomas         302875            10        4.06
# 2      Barrie M. Osborne         254857             9        4.02
# 3        Lawrence Bender         373487            27        3.99
# 4             Fran Walsh         280892             9        3.98
# 5        Stanley Kubrick         209286            10        3.97
# 6           Ceán Chaffin         206750             8        3.96
# 7          Peter Jackson         322301            18        3.94
# 8             Ethan Coen         255884            19        3.91
# 9       Steven Spielberg         347555            27        3.88
# 10         Steve Starkey         207812            15        3.82
# 11         Rick McCallum         350315            32        3.81
# 12       Gerald R. Molen         239850             9        3.81
# 13         Lorne Orleans         284869            12        3.77
# 14       Arnold Kopelson         243569            16        3.76
# 15         Charles Roven         294292            37        3.74
# 16          David Heyman         293124            30        3.72
# 17        Frank Marshall         353640            40        3.70
# 18           Kevin Feige         327996            37        3.66
# 19         James Cameron         231511            12        3.64
# 20           Joel Silver         551627            61        3.59
# 21           Scott Rudin         545770            84        3.58
# 22             Tim Bevan         250412            91        3.56
# 23         Arnon Milchan         367973            65        3.54
# 24      Walter F. Parkes         267340            30        3.54
# 25          Eric Fellner         234802            85        3.54
# 26           Mark Gordon         220266            31        3.54
# 27             Ian Bryce         232956            21        3.50
# 28      Kathleen Kennedy         452667            34        3.49
# 29  Lauren Shuler Donner         277483            32        3.46
# 30          Brian Grazer         383148            75        3.42
# 31     Jerry Bruckheimer         447379            48        3.41
# 32       Lawrence Gordon         259673            33        3.37
# 33        Roger Birnbaum         212782            53        3.24
# 34            John Davis         228857            67        3.16
#
#     top_movie_id                                    top_movie_title  \
# 0          58559                            Dark Knight, The (2008)
# 1          58559                            Dark Knight, The (2008)
# 2           4993  Lord of the Rings: The Fellowship of the Ring,...
# 3            296                                Pulp Fiction (1994)
# 4           4993  Lord of the Rings: The Fellowship of the Ring,...
# 5           1258                                Shining, The (1980)
# 6           2959                                  Fight Club (1999)
# 7           4993  Lord of the Rings: The Fellowship of the Ring,...
# 8            608                                       Fargo (1996)
# 9            527                            Schindler's List (1993)
# 10           356                                Forrest Gump (1994)
# 11           260          Star Wars: Episode IV - A New Hope (1977)
# 12           527                            Schindler's List (1993)
# 13         58559                            Dark Knight, The (2008)
# 14            47                        Seven (a.k.a. Se7en) (1995)
# 15         58559                            Dark Knight, The (2008)
# 16          4896  Harry Potter and the Sorcerer's Stone (a.k.a. ...
# 17          1198  Raiders of the Lost Ark (Indiana Jones and the...
# 18         59315                                    Iron Man (2008)
# 19           589                  Terminator 2: Judgment Day (1991)
# 20          2571                                 Matrix, The (1999)
# 21          1682                            Truman Show, The (1998)
# 22          3481                               High Fidelity (2000)
# 23           597                                Pretty Woman (1990)
# 24          1580                   Men in Black (a.k.a. MIB) (1997)
# 25         51255                                    Hot Fuzz (2007)
# 26          2028                         Saving Private Ryan (1998)
# 27          2028                         Saving Private Ryan (1998)
# 28           480                               Jurassic Park (1993)
# 29          3793                                       X-Men (2000)
# 30           150                                   Apollo 13 (1995)
# 31          6539  Pirates of the Caribbean: The Curse of the Bla...
# 32          1036                                    Die Hard (1988)
# 33           339                     While You Were Sleeping (1995)
# 34           208                                  Waterworld (1995)
#
#     top_movie_ratings
# 0               65349
# 1               65349
# 2               79940
# 3              108756
# 4               79940
# 5               40297
# 6               86207
# 7               79940
# 8               61977
# 9               84232
# 10             113581
# 11              97202
# 12              84232
# 13              65349
# 14              65666
# 15              65349
# 16              36127
# 17              75248
# 18              38308
# 19              71820
# 20             107056
# 21              45809
# 22              21317
# 23              40755
# 24              49951
# 25              21213
# 26              64235
# 27              64235
# 28              83026
# 29              42387
# 30              62521
# 31              50868
# 32              47472
# 33              26845
# 34              33098

# %% [markdown]
# #### 6.2 Best ranked 50 Actors with at least 2500000 ratings

# %%
query_top50_actors = """
WITH joined AS (
    SELECT
        a.actor_name,
        r.movieId,
        r.rating,
        a.characters
    FROM ratings r
    JOIN movielens_actors a
        ON a.movieId = r.movieId
    WHERE a.actor_name IS NOT NULL
),
actor_stats AS (
    SELECT
        actor_name,
        COUNT(*) AS total_ratings,
        COUNT(DISTINCT movieId) AS total_movies,
        ROUND(AVG(rating), 2) AS avg_rating
    FROM joined
    GROUP BY actor_name
    HAVING COUNT(*) >= 250000
),
actor_movie_ratings AS (
    SELECT
        actor_name,
        movieId,
        COUNT(*) AS movie_ratings,
        MIN(characters) AS character_name   -- caso haja duplicados, escolhe uma
    FROM joined
    GROUP BY actor_name, movieId
),
best_movie_per_actor AS (
    SELECT
        actor_name,
        movieId,
        movie_ratings,
        character_name,
        ROW_NUMBER() OVER (
            PARTITION BY actor_name
            ORDER BY movie_ratings DESC, movieId
        ) AS rn
    FROM actor_movie_ratings
)
SELECT
    s.actor_name,
    s.total_ratings,
    s.total_movies,
    s.avg_rating,
    m.movieId AS top_movie_id,
    m.title   AS top_movie_title,
    b.character_name AS top_movie_character,
    b.movie_ratings  AS top_movie_ratings
FROM actor_stats s
JOIN best_movie_per_actor b
    ON s.actor_name = b.actor_name
   AND b.rn = 1
JOIN movies m
    ON m.movieId = b.movieId
ORDER BY
    s.avg_rating DESC,
    s.total_ratings DESC
LIMIT 50;
"""

df_top50_actors = con.sql(query_top50_actors).df()
df_top50_actors
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#             actor_name  total_ratings  total_movies  avg_rating  top_movie_id  \
# 0           Sala Baker         313687             4        4.09          4993
# 1         Peter Mayhew         254428             5        4.06           260
# 2          Terry Jones         296363            13        4.04          1136
# 3        Terry Gilliam         295367            12        4.04          1136
# 4       Graham Chapman         295311            11        4.04          1136
# 5        Michael Palin         354277            25        4.00          1136
# 6          Elijah Wood         328572            43        3.96          4993
# 7        Carrie Fisher         322749            30        3.96           260
# 8          Mark Hamill         300064            47        3.96           260
# 9           Sean Astin         293481            65        3.93          4993
# 10            Tim Roth         273359            57        3.93           296
# 11       Orlando Bloom         345316            25        3.92          4993
# 12           Eric Idle         334733            29        3.92          1136
# 13      Joe Pantoliano         297338            58        3.92          2571
# 14       Robert Duvall         299013            77        3.91           858
# 15       Harrison Ford         750663            53        3.89           260
# 16           Al Pacino         335680            51        3.89           858
# 17       Edward Norton         316719            26        3.89          2959
# 18        Robin Wright         252564            34        3.89           356
# 19   John Ratzenberger         265119            31        3.88             1
# 20    Carrie-Anne Moss         250642            28        3.88          2571
# 21        Kevin Spacey         440370            58        3.87            50
# 22      Morgan Freeman         574144            94        3.85           318
# 23     Anthony Daniels         347590            18        3.85           260
# 24         Tim Robbins         295371            45        3.85           318
# 25     Viggo Mortensen         254553            40        3.85          7153
# 26        Jodie Foster         257108            37        3.84           593
# 27       Wallace Shawn         252945            67        3.84             1
# 28      Christian Bale         382378            45        3.83         33794
# 29           Sean Bean         304887            67        3.83          4993
# 30         John Cleese         435561            64        3.82          1136
# 31          Matt Damon         517305            52        3.81          2028
# 32       Ralph Fiennes         295435            53        3.81           527
# 33           Brad Pitt         646367            51        3.80          2959
# 34   Leonardo DiCaprio         438108            32        3.80         79132
# 35        Mark Ruffalo         324136            44        3.80         89745
# 36        Ian McKellen         463016            47        3.79          4993
# 37       Michael Caine         335419           107        3.79         58559
# 38        Ben Kingsley         255102            78        3.79           527
# 39           Tom Hanks         771202            72        3.77           356
# 40         Gary Oldman         388591            61        3.75         58559
# 41        Hugo Weaving         323399            33        3.75          2571
# 42      Robert De Niro         549440            98        3.74          1221
# 43     Giovanni Ribisi         262745            42        3.74          2028
# 44         Uma Thurman         302730            43        3.73           296
# 45       Tom Wilkinson         263503            71        3.73          7361
# 46  Laurence Fishburne         316114            66        3.72          2571
# 47            Frank Oz         399478            25        3.71          1196
# 48           Ed Harris         366096            73        3.71           150
# 49     Gwyneth Paltrow         269132            34        3.70            47
#
#                                       top_movie_title  \
# 0   Lord of the Rings: The Fellowship of the Ring,...
# 1           Star Wars: Episode IV - A New Hope (1977)
# 2              Monty Python and the Holy Grail (1975)
# 3              Monty Python and the Holy Grail (1975)
# 4              Monty Python and the Holy Grail (1975)
# 5              Monty Python and the Holy Grail (1975)
# 6   Lord of the Rings: The Fellowship of the Ring,...
# 7           Star Wars: Episode IV - A New Hope (1977)
# 8           Star Wars: Episode IV - A New Hope (1977)
# 9   Lord of the Rings: The Fellowship of the Ring,...
# 10                                Pulp Fiction (1994)
# 11  Lord of the Rings: The Fellowship of the Ring,...
# 12             Monty Python and the Holy Grail (1975)
# 13                                 Matrix, The (1999)
# 14                              Godfather, The (1972)
# 15          Star Wars: Episode IV - A New Hope (1977)
# 16                              Godfather, The (1972)
# 17                                  Fight Club (1999)
# 18                                Forrest Gump (1994)
# 19                                   Toy Story (1995)
# 20                                 Matrix, The (1999)
# 21                         Usual Suspects, The (1995)
# 22                   Shawshank Redemption, The (1994)
# 23          Star Wars: Episode IV - A New Hope (1977)
# 24                   Shawshank Redemption, The (1994)
# 25  Lord of the Rings: The Return of the King, The...
# 26                   Silence of the Lambs, The (1991)
# 27                                   Toy Story (1995)
# 28                               Batman Begins (2005)
# 29  Lord of the Rings: The Fellowship of the Ring,...
# 30             Monty Python and the Holy Grail (1975)
# 31                         Saving Private Ryan (1998)
# 32                            Schindler's List (1993)
# 33                                  Fight Club (1999)
# 34                                   Inception (2010)
# 35                               Avengers, The (2012)
# 36  Lord of the Rings: The Fellowship of the Ring,...
# 37                            Dark Knight, The (2008)
# 38                            Schindler's List (1993)
# 39                                Forrest Gump (1994)
# 40                            Dark Knight, The (2008)
# 41                                 Matrix, The (1999)
# 42                     Godfather: Part II, The (1974)
# 43                         Saving Private Ryan (1998)
# 44                                Pulp Fiction (1994)
# 45       Eternal Sunshine of the Spotless Mind (2004)
# 46                                 Matrix, The (1999)
# 47  Star Wars: Episode V - The Empire Strikes Back...
# 48                                   Apollo 13 (1995)
# 49                        Seven (a.k.a. Se7en) (1995)
#
#          top_movie_character  top_movie_ratings
# 0                     Goblin             239820
# 1                  Chewbacca              97202
# 2            Dennis's Mother             143535
# 3               Green Knight             143535
# 4                King Arthur             143535
# 5                     Dennis             143535
# 6                      Frodo              79940
# 7       Princess Leia Organa              97202
# 8             Luke Skywalker              97202
# 9                        Sam              79940
# 10                   Pumpkin             108756
# 11                   Legolas              79940
# 12            Dead Collector             143535
# 13                    Cypher             107056
# 14                 Tom Hagen              75004
# 15                  Han Solo              97202
# 16                   Michael              75004
# 17                  Narrator              86207
# 18              Jenny Curran             113581
# 19                      Hamm              76813
# 20                   Trinity             107056
# 21                    Verbal              72893
# 22  Ellis Boyd 'Red' Redding             122296
# 23                     C-3PO              97202
# 24             Andy Dufresne             122296
# 25                   Aragorn              75512
# 26          Clarice Starling             101802
# 27                       Rex              76813
# 28                    Batman              86600
# 29                   Boromir              79940
# 30                 Peasant 3             143535
# 31              Private Ryan              64235
# 32                Amon Goeth              84232
# 33              Tyler Durden              86207
# 34                      Cobb              65056
# 35              Bruce Banner              54990
# 36                   Gandalf              79940
# 37                    Alfred              65349
# 38              Itzhak Stern              84232
# 39              Forrest Gump             113581
# 40                    Gordon              65349
# 41               Agent Smith             107056
# 42             Vito Corleone              47271
# 43              4 Medic Wade             128470
# 44               Mia Wallace             108756
# 45             Dr. Mierzwiak              46292
# 46                  Morpheus             107056
# 47                      Yoda              80200
# 48                Gene Kranz              62521
# 49                     Tracy              65666

# %% [markdown]
# ### 6 Close conection to duckdb

# %%
con.close()
print("Ligação fechada.")
# Out:
# Ligação fechada.
