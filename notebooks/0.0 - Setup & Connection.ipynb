# %%
import sys, os
print("Python:", sys.executable)
import pandas as pd
print("pandas:", pd.__version__)

# garantir que o notebook encontra o módulo 'src'
import os, sys
sys.path.append(os.path.abspath(".."))
# Out:
# Python: /Users/pedroazevedo/Documents/GitHub/BigDataFoundations/.venv-franco/bin/python
# pandas: 2.3.3

# %%
from src.utils import get_athena_connection, read_sql_df
from src.config import DB_ATHENA

conn = get_athena_connection()

# mostra as tabelas do Athena
sql = f"SHOW TABLES IN {DB_ATHENA};"
tables = read_sql_df(sql, conn)
tables
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from src.utils import get_athena_connection, read_sql_df
#       2 from src.config import DB_ATHENA
#       4 conn = get_athena_connection()
#
# File ~/Documents/GitHub/BigDataFoundations/src/utils.py:4
#       2 import pandas as pd
#       3 from pyathena import connect
# ----> 4 from .config import REGION, S3_STAGING, DB_ATHENA
#       6 def get_athena_connection(work_group="primary"):
#       7     return connect(
#       8         s3_staging_dir=S3_STAGING,
#       9         region_name=REGION,
#      10         work_group=work_group,
#      11         schema_name=DB_ATHENA,
#      12     )
#
# File ~/Documents/GitHub/BigDataFoundations/src/config.py:2
#       1 import os
# ----> 2 from dotenv import load_dotenv
#       4 # carregar variáveis do ficheiro .env
#       5 load_dotenv()
#
# ...

# %%
##teste

df_test = read_sql_df("SELECT * FROM movielens1m.movies_parquet LIMIT 5;", conn)
df_test.head()
# Out:
# c:\Users\sarac\rep_DSF\BigDataFoundations\src\utils.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn)
#    movieid                               title                        genres
# 0        1                    Toy Story (1995)   Animation|Children's|Comedy
# 1        2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2        3             Grumpier Old Men (1995)                Comedy|Romance
# 3        4            Waiting to Exhale (1995)                  Comedy|Drama
# 4        5  Father of the Bride Part II (1995)                        Comedy

# %%
df_test = read_sql_df("SELECT * FROM movielens1m.ratings_parquet LIMIT 5;", conn)
df_test.head()
# Out:
# c:\Users\sarac\rep_DSF\BigDataFoundations\src\utils.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn)
#    user_id  movie_id  rating           rating_ts
# 0        1      1193     5.0 2000-12-31 22:12:40
# 1        1       661     3.0 2000-12-31 22:35:09
# 2        1       914     3.0 2000-12-31 22:32:48
# 3        1      3408     4.0 2000-12-31 22:04:35
# 4        1      2355     5.0 2001-01-06 23:38:11

# %%
df_test = read_sql_df("SELECT * FROM movielens1m.users_parquet LIMIT 5;", conn)
df_test.head()
# Out:
# c:\Users\sarac\rep_DSF\BigDataFoundations\src\utils.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn)
#    user_id gender  age  occupation zipcode
# 0        1      F    1          10   48067
# 1        4      M   45           7   02460
# 2        5      M   25          20   55455
# 3        2      M   56          16   70072
# 4        3      M   25          15   55117
