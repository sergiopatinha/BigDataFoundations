# %%
import pandas as pd

import os, sys
sys.path.append(os.path.abspath(".."))

from src.utils import get_athena_connection, read_sql_df
from src.config import DB_ATHENA


# ligação Athena
conn = get_athena_connection()
print(f"Connected with Athena base:'{DB_ATHENA}'")

def run_sql(sql: str) -> pd.DataFrame:
    """
    Executa SQL no Athena (MovieLens 1M) e devolve um DataFrame pandas.
    """
    return read_sql_df(sql, conn=conn)
# Out:
# Connected with Athena base:'movielens1m'

# %%
BASE = "s3://bdf25-20-movielens/curated"


# 4) Verificação, agora em Athena
run_sql("SHOW TABLES")
run_sql("SELECT * FROM ratings_parquet LIMIT 5")
# Out:
# c:\Users\sarac\rep_DSF\BigDataFoundations\src\utils.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn)
# Failed to execute query.
# Traceback (most recent call last):
#   File "c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\pyathena\common.py", line 645, in _execute
#     query_id = retry_api_call(
#                ~~~~~~~~~~~~~~^
#         self._connection.client.start_query_execution,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<2 lines>...
#         **request,
#         ^^^^^^^^^^
#     ).get("QueryExecutionId")
#     ^
#   File "c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\pyathena\util.py", line 196, in retry_api_call
#     return retry(func, *args, **kwargs)
#   File "c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\tenacity\__init__.py", line 477, in __call__
#     do = self.iter(retry_state=retry_state)
#   File "c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\tenacity\__init__.py", line 378, in iter
#     result = action(retry_state)
#   File "c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\tenacity\__init__.py", line 400, in <lambda>
#     self._add_action_func(lambda rs: rs.outcome.result())
#                                      ~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\sarac\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\_base.py", line 449, in result
#     return self.__get_result()
#            ~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\sarac\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\_base.py", line 401, in __get_result
#     raise self._exception
#   File "c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\tenacity\__init__.py", line 480, in __call__
#     result = fn(*args, **kwargs)
#   File "c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\botocore\client.py", line 602, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\botocore\context.py", line 123, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\botocore\client.py", line 1078, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.exceptions.ClientError: An error occurred (AccessDeniedException) when calling the StartQueryExecution operation: You are not authorized to perform: athena:StartQueryExecution on the resource. After your AWS administrator or you have updated your permissions, please try again.
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\pyathena\common.py:645, in BaseCursor._execute(self, operation, parameters, work_group, s3_staging_dir, cache_size, cache_expiration_time, result_reuse_enable, result_reuse_minutes, paramstyle)
#     644 try:
# --> 645     query_id = retry_api_call(
#     646         self._connection.client.start_query_execution,
#     647         config=self._retry_config,
#     648         logger=_logger,
#     649         **request,
#     650     ).get("QueryExecutionId")
#     651 except Exception as e:
#
# File c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\pyathena\util.py:196, in retry_api_call(func, config, logger, *args, **kwargs)
#     185 retry = tenacity.Retrying(
#     186     retry=retry_if_exception(_is_retryable),
#     187     stop=stop_after_attempt(config.attempt),
#    (...)    194     reraise=True,
#     195 )
# --> 196 return retry(func, *args, **kwargs)
#
# File c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#
# File c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\tenacity\__init__.py:400, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     399 if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 400     self._add_action_func(lambda rs: rs.outcome.result())
#     401     return
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     479 try:
# --> 480     result = fn(*args, **kwargs)
#     481 except BaseException:  # noqa: B902
#
# File c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\botocore\client.py:602, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     601 # The "self" in this scope is referring to the BaseClient.
# --> 602 return self._make_api_call(operation_name, kwargs)
#
# File c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\botocore\context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\botocore\client.py:1078, in BaseClient._make_api_call(self, operation_name, api_params)
#    1077     error_class = self.exceptions.from_code(error_code)
# -> 1078     raise error_class(parsed_response, operation_name)
#    1079 else:
#
# ClientError: An error occurred (AccessDeniedException) when calling the StartQueryExecution operation: You are not authorized to perform: athena:StartQueryExecution on the resource. After your AWS administrator or you have updated your permissions, please try again.
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# File c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\pandas\io\sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# File c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\pyathena\cursor.py:190, in Cursor.execute(self, operation, parameters, work_group, s3_staging_dir, cache_size, cache_expiration_time, result_reuse_enable, result_reuse_minutes, paramstyle, on_start_query_execution, **kwargs)
#     189 self._reset_state()
# --> 190 self.query_id = self._execute(
#     191     operation,
#     192     parameters=parameters,
#     193     work_group=work_group,
#     194     s3_staging_dir=s3_staging_dir,
#     195     cache_size=cache_size,
#     196     cache_expiration_time=cache_expiration_time,
#     197     result_reuse_enable=result_reuse_enable,
#     198     result_reuse_minutes=result_reuse_minutes,
#     199     paramstyle=paramstyle,
#     200 )
#     202 # Call user callbacks immediately after start_query_execution
#     203 # Both connection-level and execute-level callbacks are invoked if set
#
# File c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\pyathena\common.py:653, in BaseCursor._execute(self, operation, parameters, work_group, s3_staging_dir, cache_size, cache_expiration_time, result_reuse_enable, result_reuse_minutes, paramstyle)
#     652         _logger.exception("Failed to execute query.")
# --> 653         raise DatabaseError(*e.args) from e
#     654 return query_id
#
# DatabaseError: An error occurred (AccessDeniedException) when calling the StartQueryExecution operation: You are not authorized to perform: athena:StartQueryExecution on the resource. After your AWS administrator or you have updated your permissions, please try again.
#
# During handling of the above exception, another exception occurred:
#
# NotSupportedError                         Traceback (most recent call last)
# File c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\pandas\io\sql.py:2668, in SQLiteDatabase.execute(self, sql, params)
#    2667 try:
# -> 2668     self.con.rollback()
#    2669 except Exception as inner_exc:  # pragma: no cover
#
# File c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\pyathena\connection.py:586, in Connection.rollback(self)
#     578 """Rollback any pending transaction.
#     579
#     580 This method is required by DB API 2.0 but is not supported by Athena
#    (...)    584     NotSupportedError: Always raised since transactions are not supported.
#     585 """
# --> 586 raise NotSupportedError
#
# NotSupportedError:
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[2], line 5
#       1 BASE = "s3://bdf25-20-movielens/curated"
#       4 # 4) Verificação, agora em Athena
# ----> 5 run_sql("SHOW TABLES")
#       6 run_sql("SELECT * FROM ratings_parquet LIMIT 5")
#
# Cell In[1], line 18, in run_sql(sql)
#      14 def run_sql(sql: str) -> pd.DataFrame:
#      15     """
#      16     Executa SQL no Athena (MovieLens 1M) e devolve um DataFrame pandas.
#      17     """
# ---> 18     return read_sql_df(sql, conn=conn)
#
# File c:\Users\sarac\rep_DSF\BigDataFoundations\src\utils.py:19, in read_sql_df(sql, conn)
#      17     conn = get_athena_connection()
#      18     close = True
# ---> 19 df = pd.read_sql(sql, conn)
#      20 if close:
#      21     conn.close()
#
# File c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\pandas\io\sql.py:708, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     706 with pandasSQL_builder(con) as pandas_sql:
#     707     if isinstance(pandas_sql, SQLiteDatabase):
# --> 708         return pandas_sql.read_query(
#     709             sql,
#     710             index_col=index_col,
#     711             params=params,
#     712             coerce_float=coerce_float,
#     713             parse_dates=parse_dates,
#     714             chunksize=chunksize,
#     715             dtype_backend=dtype_backend,
#     716             dtype=dtype,
#     717         )
#     719     try:
#     720         _is_table_name = pandas_sql.has_table(sql)
#
# File c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\pandas\io\sql.py:2728, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2717 def read_query(
#    2718     self,
#    2719     sql,
#    (...)   2726     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2727 ) -> DataFrame | Iterator[DataFrame]:
# -> 2728     cursor = self.execute(sql, params)
#    2729     columns = [col_desc[0] for col_desc in cursor.description]
#    2731     if chunksize is not None:
#
# File c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\pandas\io\sql.py:2673, in SQLiteDatabase.execute(self, sql, params)
#    2669 except Exception as inner_exc:  # pragma: no cover
#    2670     ex = DatabaseError(
#    2671         f"Execution failed on sql: {sql}\n{exc}\nunable to rollback"
#    2672     )
# -> 2673     raise ex from inner_exc
#    2675 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
#    2676 raise ex from exc
#
# DatabaseError: Execution failed on sql: SHOW TABLES
# An error occurred (AccessDeniedException) when calling the StartQueryExecution operation: You are not authorized to perform: athena:StartQueryExecution on the resource. After your AWS administrator or you have updated your permissions, please try again.
# unable to rollback

# %% [markdown]
# #### Comment
#
# - `userId`: INTEGER
# - `movieId`: INTEGER
# - `rating`: DOUBLE
# - `timestamp`: TIMESTAMP WITH TIME ZONE
#
# - The `null` column indicates whether the field can contain null (NULL) values.
#   - In this case, it can.
#
# - The `key` column indicates whether the field is a primary key (PRIMARY KEY).
#   - It is not.
#
# - The `default` column shows the default value (DEFAULT).
#   - None.
#
# - The `extra` column displays additional information about the field, such as auto_increment or generated.
#   - None in this case.

# %%
#see data types of each column
con.sql("PRAGMA table_info('ratings')").df()
# Out:
#    cid       name                      type  notnull dflt_value     pk
# 0    0     userId                   INTEGER    False       None  False
# 1    1    movieId                   INTEGER    False       None  False
# 2    2     rating                    DOUBLE    False       None  False
# 3    3  timestamp  TIMESTAMP WITH TIME ZONE    False       None  False

# %%
#see first 10 rows
con.sql("SELECT * FROM ratings LIMIT 10;").df()
# Out:
#    userId  movieId  rating                 timestamp
# 0       1        1     4.0 2008-11-03 17:52:19+00:00
# 1       1      110     4.0 2008-11-05 06:04:46+00:00
# 2       1      158     4.0 2008-11-03 17:31:43+00:00
# 3       1      260     4.5 2008-11-03 18:00:04+00:00
# 4       1      356     5.0 2008-11-03 17:58:39+00:00
# 5       1      381     3.5 2008-11-03 17:41:45+00:00
# 6       1      596     4.0 2008-11-03 17:32:04+00:00
# 7       1     1036     5.0 2008-11-03 18:07:06+00:00
# 8       1     1049     3.0 2008-11-03 17:41:19+00:00
# 9       1     1066     4.0 2008-11-03 18:29:21+00:00

# %%
#Count number of missing values
con.sql("""
SELECT
    COUNT(*) - COUNT(userId)   AS missing_userId,
    COUNT(*) - COUNT(movieId)  AS missing_movieId,
    COUNT(*) - COUNT(rating)   AS missing_rating,
    COUNT(*) - COUNT(timestamp) AS missing_timestamp
FROM ratings
""").df()
# Out:
#    missing_userId  missing_movieId  missing_rating  missing_timestamp
# 0               0                0               0                  0

# %%
#Identification of maximum, minimum values and counts of ratings
con.sql("""
SELECT
    MIN(userId)                  AS min_userId,
    MAX(userId)                  AS max_userId,
    COUNT(DISTINCT userId)       AS total_users,
    MIN(movieId)                 AS min_movieId,
    MAX(movieId)                 AS max_movieId,
    COUNT(DISTINCT movieId)      AS total_movies,
    MIN(rating)                  AS min_rating,
    MAX(rating)                  AS max_rating,
    AVG(rating)                  AS med_rating,
    MIN(timestamp)               AS min_timestamp,
    MAX(timestamp)               AS max_timestamp,
    COUNT(*)                     AS total_ratings
        
FROM ratings
""").df()
# Out:
#    min_userId  max_userId  total_users  min_movieId  max_movieId  \
# 0           1      330975       330975            1       288983
#
#    total_movies  min_rating  max_rating  med_rating             min_timestamp  \
# 0         83239         0.5         5.0     3.54254 1995-01-09 12:46:44+01:00
#
#               max_timestamp  total_ratings
# 0 2023-07-20 09:53:33+01:00       33832162

# %% [markdown]
# #### Comments
#
# - There are 330,975 unique user IDs providing ratings.
# - A total of 83,239 movies have been evaluated.
# - Ratings range from 0.5 to 5.0, with an average value of 3.54254.
# - The earliest rating timestamp is from January 9, 1995, at 12:46:44+01:00.
# - The most recent rating timestamp is from July 7, 2023, at 09:53:33+01:00.
# - The dataset contains a total of 33,832,162 ratings (rows).

# %%
#Number of ratings and average rating per user
con.sql("""
SELECT
    userId,
    COUNT(*)              AS total_ratings,
    ROUND(AVG(rating), 2) AS media_rating
FROM ratings
GROUP BY userId
ORDER BY total_ratings DESC, media_rating DESC
""").df()
# Out:
#         userId  total_ratings  media_rating
# 0       189614          33332          3.08
# 1        48766           9554          2.57
# 2       207216           9178          3.28
# 3       175998           9016          3.18
# 4        76618           8919          2.54
# ...        ...            ...           ...
# 330970   56881              1          0.50
# 330971   95533              1          0.50
# 330972  126444              1          0.50
# 330973  283799              1          0.50
# 330974  316947              1          0.50
#
# [330975 rows x 3 columns]

# %% [markdown]
# #### Comentários
#  - User 189,614 had rated 33332 movies, with an average rating of 3.08 . This means that if this user watched 1 movie a day, he/she would need 91 years to watch all these movies, thus there's probably a bot or an agencie behind this number. Also to mentioned that this number very far from the second to fourth user with around 9K movies rated.

# %%
#average ratings per movie ordered from best to worst rating
con.sql("""
SELECT
    m.title,
    ROUND(AVG(r.rating), 2) AS media_rating,
    COUNT(*)                AS total_ratings
FROM ratings r
JOIN movies m USING (movieId)
GROUP BY m.title
ORDER BY media_rating DESC, total_ratings DESC
""").df()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#                                          title  media_rating  total_ratings
# 0      The Matrix Revolutions Revisited (2004)           5.0              4
# 1         David Attenborough's Tasmania (2018)           5.0              3
# 2                    Sound of Christmas (2016)           5.0              3
# 3                                Awaken (2013)           5.0              3
# 4                         Love, Kennedy (2017)           5.0              3
# ...                                        ...           ...            ...
# 83038                       The Cop Cam (2016)           0.5              1
# 83039                   Chainsaw Maid 2 (2010)           0.5              1
# 83040                         Yesterday (2018)           0.5              1
# 83041                    Akte Grüninger (2014)           0.5              1
# 83042                  The Tiger Rising (2022)           0.5              1
#
# [83043 rows x 3 columns]

# %%
#average ratings per movie ordered from most rated to least rated
con.sql("""
SELECT
    m.title,
    ROUND(AVG(r.rating), 2) AS media_rating,
    COUNT(*)                AS total_ratings
FROM ratings r
JOIN movies m USING (movieId)
GROUP BY m.title
ORDER BY total_ratings DESC, media_rating DESC
""").df()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#                                   title  media_rating  total_ratings
# 0      Shawshank Redemption, The (1994)          4.42         122296
# 1                   Forrest Gump (1994)          4.07         113581
# 2                   Pulp Fiction (1994)          4.19         108756
# 3                    Matrix, The (1999)          4.16         107056
# 4      Silence of the Lambs, The (1991)          4.15         101802
# ...                                 ...           ...            ...
# 83038           Zombie Infection (2011)          0.50              1
# 83039    Humanoids from Atlantis (1992)          0.50              1
# 83040                  Yesterday (2018)          0.50              1
# 83041             Akte Grüninger (2014)          0.50              1
# 83042           The Tiger Rising (2022)          0.50              1
#
# [83043 rows x 3 columns]

# %%
con.sql("""
WITH counts AS (
  SELECT movieId, COUNT(*)::BIGINT AS n_ratings
  FROM ratings
  GROUP BY movieId
)
SELECT
  quantile_cont(n_ratings, 0.25) AS p25_ratings,
  quantile_cont(n_ratings, 0.50) AS median_ratings,
  quantile_cont(n_ratings, 0.75) AS p75_ratings,
  MIN(n_ratings) AS min_ratings,
  MAX(n_ratings) AS max_ratings,
  AVG(n_ratings)::DOUBLE AS mean_ratings
FROM counts
""").df()
# Out:
#    p25_ratings  median_ratings  p75_ratings  min_ratings  max_ratings  \
# 0          2.0             5.0         26.0            1       122296
#
#    mean_ratings
# 0    406.446041

# %% [markdown]
# ### Conclusion
#
# - Most movies have less than 26 ratings (q3), with a median of 5 ratings.

# %% [markdown]
# #### Fechar a ligação

# %%
con.close()
print("Ligação fechada.")
# Out:
# Ligação fechada.
