# %%
import pandas as pd

import os, sys
sys.path.append(os.path.abspath(".."))

from src.utils import get_athena_connection, read_sql_df
from src.config import DB_ATHENA


# ligação Athena
conn = get_athena_connection()
print(f"Connected with Athena base:'{DB_ATHENA}'")

def run_sql(sql: str) -> pd.DataFrame:
    """
    Executa SQL no Athena (MovieLens 1M) e devolve um DataFrame pandas.
    """
    return read_sql_df(sql, conn=conn)
# Out:
# Connected with Athena base:'movielens1m'

# %%
BASE = "s3://bdf25-20-movielens/curated/"


# 4) Verificação, agora em Athena
run_sql("SHOW TABLES")
run_sql("SELECT * FROM ratings_parquet LIMIT 5")
# Out:
#    userid  movieid  rating           timestamp
# 0       1     1193     5.0 2000-12-31 22:12:40
# 1       1      661     3.0 2000-12-31 22:35:09
# 2       1      914     3.0 2000-12-31 22:32:48
# 3       1     3408     4.0 2000-12-31 22:04:35
# 4       1     2355     5.0 2001-01-06 23:38:11

# %%
run_sql("SHOW COLUMNS FROM ratings_parquet")
# Out:
# c:\Users\sarac\rep_DSF\BigDataFoundations\src\utils.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn)
#                   field
# 0  user_id
# 1  movie_id
# 2  rating
# 3  rating_ts

# %%
run_sql(f"""
SELECT
    column_name,
    data_type,
    is_nullable
FROM information_schema.columns
WHERE table_schema = '{DB_ATHENA}'
  AND table_name   = 'ratings_parquet'
ORDER BY ordinal_position
""")
# Out:
# c:\Users\sarac\rep_DSF\BigDataFoundations\src\utils.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn)
#   column_name     data_type is_nullable
# 0     user_id       integer         YES
# 1    movie_id       integer         YES
# 2      rating        double         YES
# 3   rating_ts  timestamp(3)         YES

# %% [markdown]
# #### Comment
#
# - `userId`: INTEGER
# - `movieId`: INTEGER
# - `rating`: DOUBLE
# - `timestamp`: TIMESTAMP WITH PRECISION OF MILISECONDS
#
# - The column `is_nullable` is `YES` for all fields.
#   - This means the table allows null (NULL) values.
#   - Because the data was loaded from external files, there are no enforced NOT NULL constraints.

# %%
#see first 10 rows

run_sql("SELECT * FROM ratings_parquet LIMIT 10")
# Out:
# c:\Users\sarac\rep_DSF\BigDataFoundations\src\utils.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn)
#    user_id  movie_id  rating           rating_ts
# 0        1      1193     5.0 2000-12-31 22:12:40
# 1        1       661     3.0 2000-12-31 22:35:09
# 2        1       914     3.0 2000-12-31 22:32:48
# 3        1      3408     4.0 2000-12-31 22:04:35
# 4        1      2355     5.0 2001-01-06 23:38:11
# 5        1      1197     3.0 2000-12-31 22:37:48
# 6        1      1287     5.0 2000-12-31 22:33:59
# 7        1      2804     5.0 2000-12-31 22:11:59
# 8        1       594     4.0 2000-12-31 22:37:48
# 9        1       919     4.0 2000-12-31 22:22:48

# %%
#Count number of missing values
run_sql("""
SELECT
    COUNT(*) - COUNT(movieId) AS missing_movieId,
    COUNT(*) - COUNT(title)   AS missing_title,
    COUNT(*) - COUNT(genres)  AS missing_genres
FROM ratings_parquet
""")
# Out:
# c:\Users\sarac\rep_DSF\BigDataFoundations\src\utils.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn)
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\pandas\io\sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# File c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\pyathena\cursor.py:219, in Cursor.execute(self, operation, parameters, work_group, s3_staging_dir, cache_size, cache_expiration_time, result_reuse_enable, result_reuse_minutes, paramstyle, on_start_query_execution, **kwargs)
#     218 else:
# --> 219     raise OperationalError(query_execution.state_change_reason)
#     220 return self
#
# OperationalError: COLUMN_NOT_FOUND: line 2:22: Column 'movieid' cannot be resolved or requester is not authorized to access requested resources
#
# During handling of the above exception, another exception occurred:
#
# NotSupportedError                         Traceback (most recent call last)
# File c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\pandas\io\sql.py:2668, in SQLiteDatabase.execute(self, sql, params)
#    2667 try:
# -> 2668     self.con.rollback()
#    2669 except Exception as inner_exc:  # pragma: no cover
#
# File c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\pyathena\connection.py:586, in Connection.rollback(self)
#     578 """Rollback any pending transaction.
#     579
#     580 This method is required by DB API 2.0 but is not supported by Athena
#    (...)    584     NotSupportedError: Always raised since transactions are not supported.
#     585 """
# --> 586 raise NotSupportedError
#
# NotSupportedError:
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[9], line 2
#       1 #Count number of missing values
# ----> 2 run_sql("""
#       3 SELECT
#       4     COUNT(*) - COUNT(movieId) AS missing_movieId,
#       5     COUNT(*) - COUNT(title)   AS missing_title,
#       6     COUNT(*) - COUNT(genres)  AS missing_genres
#       7 FROM ratings_parquet
#       8 """)
#
# Cell In[1], line 18, in run_sql(sql)
#      14 def run_sql(sql: str) -> pd.DataFrame:
#      15     """
#      16     Executa SQL no Athena (MovieLens 1M) e devolve um DataFrame pandas.
#      17     """
# ---> 18     return read_sql_df(sql, conn=conn)
#
# File c:\Users\sarac\rep_DSF\BigDataFoundations\src\utils.py:19, in read_sql_df(sql, conn)
#      17     conn = get_athena_connection()
#      18     close = True
# ---> 19 df = pd.read_sql(sql, conn)
#      20 if close:
#      21     conn.close()
#
# File c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\pandas\io\sql.py:708, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     706 with pandasSQL_builder(con) as pandas_sql:
#     707     if isinstance(pandas_sql, SQLiteDatabase):
# --> 708         return pandas_sql.read_query(
#     709             sql,
#     710             index_col=index_col,
#     711             params=params,
#     712             coerce_float=coerce_float,
#     713             parse_dates=parse_dates,
#     714             chunksize=chunksize,
#     715             dtype_backend=dtype_backend,
#     716             dtype=dtype,
#     717         )
#     719     try:
#     720         _is_table_name = pandas_sql.has_table(sql)
#
# File c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\pandas\io\sql.py:2728, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2717 def read_query(
#    2718     self,
#    2719     sql,
#    (...)   2726     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2727 ) -> DataFrame | Iterator[DataFrame]:
# -> 2728     cursor = self.execute(sql, params)
#    2729     columns = [col_desc[0] for col_desc in cursor.description]
#    2731     if chunksize is not None:
#
# File c:\Users\sarac\rep_DSF\BigDataFoundations\.venv\Lib\site-packages\pandas\io\sql.py:2673, in SQLiteDatabase.execute(self, sql, params)
#    2669 except Exception as inner_exc:  # pragma: no cover
#    2670     ex = DatabaseError(
#    2671         f"Execution failed on sql: {sql}\n{exc}\nunable to rollback"
#    2672     )
# -> 2673     raise ex from inner_exc
#    2675 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
#    2676 raise ex from exc
#
# DatabaseError: Execution failed on sql:
# SELECT
#     COUNT(*) - COUNT(movieId) AS missing_movieId,
#     COUNT(*) - COUNT(title)   AS missing_title,
#     COUNT(*) - COUNT(genres)  AS missing_genres
# FROM ratings_parquet
#
# COLUMN_NOT_FOUND: line 2:22: Column 'movieid' cannot be resolved or requester is not authorized to access requested resources
# unable to rollback

# %%
#Identification of maximum, minimum values and counts of ratings
con.sql("""
SELECT
    MIN(userId)                  AS min_userId,
    MAX(userId)                  AS max_userId,
    COUNT(DISTINCT userId)       AS total_users,
    MIN(movieId)                 AS min_movieId,
    MAX(movieId)                 AS max_movieId,
    COUNT(DISTINCT movieId)      AS total_movies,
    MIN(rating)                  AS min_rating,
    MAX(rating)                  AS max_rating,
    AVG(rating)                  AS med_rating,
    MIN(timestamp)               AS min_timestamp,
    MAX(timestamp)               AS max_timestamp,
    COUNT(*)                     AS total_ratings
        
FROM ratings
""").df()
# Out:
#    min_userId  max_userId  total_users  min_movieId  max_movieId  \
# 0           1      330975       330975            1       288983
#
#    total_movies  min_rating  max_rating  med_rating             min_timestamp  \
# 0         83239         0.5         5.0     3.54254 1995-01-09 12:46:44+01:00
#
#               max_timestamp  total_ratings
# 0 2023-07-20 09:53:33+01:00       33832162

# %% [markdown]
# #### Comments
#
# - There are 330,975 unique user IDs providing ratings.
# - A total of 83,239 movies have been evaluated.
# - Ratings range from 0.5 to 5.0, with an average value of 3.54254.
# - The earliest rating timestamp is from January 9, 1995, at 12:46:44+01:00.
# - The most recent rating timestamp is from July 7, 2023, at 09:53:33+01:00.
# - The dataset contains a total of 33,832,162 ratings (rows).

# %%
#Number of ratings and average rating per user
con.sql("""
SELECT
    userId,
    COUNT(*)              AS total_ratings,
    ROUND(AVG(rating), 2) AS media_rating
FROM ratings
GROUP BY userId
ORDER BY total_ratings DESC, media_rating DESC
""").df()
# Out:
#         userId  total_ratings  media_rating
# 0       189614          33332          3.08
# 1        48766           9554          2.57
# 2       207216           9178          3.28
# 3       175998           9016          3.18
# 4        76618           8919          2.54
# ...        ...            ...           ...
# 330970   56881              1          0.50
# 330971   95533              1          0.50
# 330972  126444              1          0.50
# 330973  283799              1          0.50
# 330974  316947              1          0.50
#
# [330975 rows x 3 columns]

# %% [markdown]
# #### Comentários
#  - User 189,614 had rated 33332 movies, with an average rating of 3.08 . This means that if this user watched 1 movie a day, he/she would need 91 years to watch all these movies, thus there's probably a bot or an agencie behind this number. Also to mentioned that this number very far from the second to fourth user with around 9K movies rated.

# %%
#average ratings per movie ordered from best to worst rating
con.sql("""
SELECT
    m.title,
    ROUND(AVG(r.rating), 2) AS media_rating,
    COUNT(*)                AS total_ratings
FROM ratings r
JOIN movies m USING (movieId)
GROUP BY m.title
ORDER BY media_rating DESC, total_ratings DESC
""").df()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#                                          title  media_rating  total_ratings
# 0      The Matrix Revolutions Revisited (2004)           5.0              4
# 1         David Attenborough's Tasmania (2018)           5.0              3
# 2                    Sound of Christmas (2016)           5.0              3
# 3                                Awaken (2013)           5.0              3
# 4                         Love, Kennedy (2017)           5.0              3
# ...                                        ...           ...            ...
# 83038                       The Cop Cam (2016)           0.5              1
# 83039                   Chainsaw Maid 2 (2010)           0.5              1
# 83040                         Yesterday (2018)           0.5              1
# 83041                    Akte Grüninger (2014)           0.5              1
# 83042                  The Tiger Rising (2022)           0.5              1
#
# [83043 rows x 3 columns]

# %%
#average ratings per movie ordered from most rated to least rated
con.sql("""
SELECT
    m.title,
    ROUND(AVG(r.rating), 2) AS media_rating,
    COUNT(*)                AS total_ratings
FROM ratings r
JOIN movies m USING (movieId)
GROUP BY m.title
ORDER BY total_ratings DESC, media_rating DESC
""").df()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#                                   title  media_rating  total_ratings
# 0      Shawshank Redemption, The (1994)          4.42         122296
# 1                   Forrest Gump (1994)          4.07         113581
# 2                   Pulp Fiction (1994)          4.19         108756
# 3                    Matrix, The (1999)          4.16         107056
# 4      Silence of the Lambs, The (1991)          4.15         101802
# ...                                 ...           ...            ...
# 83038           Zombie Infection (2011)          0.50              1
# 83039    Humanoids from Atlantis (1992)          0.50              1
# 83040                  Yesterday (2018)          0.50              1
# 83041             Akte Grüninger (2014)          0.50              1
# 83042           The Tiger Rising (2022)          0.50              1
#
# [83043 rows x 3 columns]

# %%
con.sql("""
WITH counts AS (
  SELECT movieId, COUNT(*)::BIGINT AS n_ratings
  FROM ratings
  GROUP BY movieId
)
SELECT
  quantile_cont(n_ratings, 0.25) AS p25_ratings,
  quantile_cont(n_ratings, 0.50) AS median_ratings,
  quantile_cont(n_ratings, 0.75) AS p75_ratings,
  MIN(n_ratings) AS min_ratings,
  MAX(n_ratings) AS max_ratings,
  AVG(n_ratings)::DOUBLE AS mean_ratings
FROM counts
""").df()
# Out:
#    p25_ratings  median_ratings  p75_ratings  min_ratings  max_ratings  \
# 0          2.0             5.0         26.0            1       122296
#
#    mean_ratings
# 0    406.446041

# %% [markdown]
# ### Conclusion
#
# - Most movies have less than 26 ratings (q3), with a median of 5 ratings.

# %% [markdown]
# #### Fechar a ligação

# %%
con.close()
print("Ligação fechada.")
# Out:
# Ligação fechada.
