# %% [markdown]
# ### 1 Importing libraries, Data and data conversion
# #### 1.1 Download Data & Setup up files
# Download the 33M MovieLens dataset from:
# https://grouplens.org/datasets/movielens/latest/
#
# Create a folder named data, and inside it create a subfolder called Full33M.
# Place all the downloaded files from the 33M dataset into this folder and unzip them.
#
# #### 1.2 pip instal

# %%
#if you are in need to install dependencies in your venv, uncomment the line below.
# %pip install duckdb pandas
# Out:
# Requirement already satisfied: duckdb in c:\users\sarac\rep_dsf\bigdatafoundations\.venv\lib\site-packages (1.4.1)
# Requirement already satisfied: pandas in c:\users\sarac\rep_dsf\bigdatafoundations\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\sarac\rep_dsf\bigdatafoundations\.venv\lib\site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sarac\rep_dsf\bigdatafoundations\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sarac\rep_dsf\bigdatafoundations\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sarac\rep_dsf\bigdatafoundations\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\sarac\rep_dsf\bigdatafoundations\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### 1.3 Importing libraries and folder paths

# %%
import duckdb, pandas as pd
from pathlib import Path
import os
 
DATA_DIR = Path("..") / "data" / "Full33M"
#movies_path
 
links_csv = DATA_DIR / "links.csv"
movies_csv = DATA_DIR / "movies.csv"
ratings_csv = DATA_DIR / "ratings.csv"
tags_csv = DATA_DIR / "tags.csv"


# diretório para guardar parquet
PARQUET_DIR = DATA_DIR / "parquet"
PARQUET_DIR.mkdir(exist_ok=True)

# %% [markdown]
# #### 1.4 Creating function to create parque files

# %%
def safe_copy_to_parquet(csv_path, parquet_path, sql_select):
    if parquet_path.exists():
        print(f"Deleting existing file: {parquet_path}")
        os.remove(parquet_path)

    print(f"Creating parquet file: {parquet_path}")

    duckdb.sql(f"""
    COPY (
        {sql_select}
    ) TO '{parquet_path}'
    (FORMAT 'parquet');
    """)

    print(f"✔ Finished writing {parquet_path}\n")

# %% [markdown]
# #### 1.5 Creating Parquet files
# ##### 1.5.1 movies.parquet

# %%
# converter movies
safe_copy_to_parquet(
    movies_csv,
    PARQUET_DIR / "movies.parquet",
    f"SELECT * FROM read_csv_auto('{movies_csv}')"
)
# Out:
# Creating parquet file: ..\data\Full33M\parquet\movies.parquet
# ✔ Finished writing ..\data\Full33M\parquet\movies.parquet

# %% [markdown]
# ##### 1.5.2 ratings.parquet

# %%
# ratings parquet with correct types
duckdb.sql(f"""
COPY (
    SELECT
        userId::INT     AS userId,
        movieId::INT    AS movieId,
        rating::DOUBLE  AS rating,
        to_timestamp(CAST(timestamp AS BIGINT)) AS timestamp
    FROM read_csv_auto('{ratings_csv}')
) TO '{PARQUET_DIR / "ratings.parquet"}'
(FORMAT 'parquet');
""")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %% [markdown]
# ##### 1.5.3 tags.parquet

# %%
# tags parquet with correct types
duckdb.sql(f"""
COPY (
    SELECT
        userId::INT     AS userId,
        movieId::INT    AS movieId,
        tag,
        to_timestamp(CAST(timestamp AS BIGINT)) AS timestamp
    FROM read_csv_auto('{tags_csv}')
) TO '{PARQUET_DIR / "tags.parquet"}'
(FORMAT 'parquet');
""")

# %% [markdown]
# ##### 1.5.4 links.parquet

# %%
# converter links
safe_copy_to_parquet(
    links_csv,
    PARQUET_DIR / "links.parquet",
    f"SELECT * FROM read_csv_auto('{links_csv}')"
)
# Out:
# Creating parquet file: ..\data\Full33M\parquet\links.parquet
# ✔ Finished writing ..\data\Full33M\parquet\links.parquet

# %% [markdown]
# ### 2.0 Creating tables in Duckdb

# %%
con = duckdb.connect("movielensfull33M.duckdb")

con.sql(f"CREATE OR REPLACE TABLE movies  AS SELECT * FROM read_parquet('{PARQUET_DIR / "movies.parquet"}')")
con.sql(f"CREATE OR REPLACE TABLE ratings AS SELECT * FROM read_parquet('{PARQUET_DIR / "ratings.parquet"}')")
con.sql(f"CREATE OR REPLACE TABLE tags    AS SELECT * FROM read_parquet('{PARQUET_DIR / "tags.parquet"}')")
con.sql(f"CREATE OR REPLACE TABLE links   AS SELECT * FROM read_parquet('{PARQUET_DIR / "links.parquet"}')")

# %%
# show final state
con.sql("SHOW TABLES").df()
# Out:
#       name
# 0    links
# 1   movies
# 2  ratings
# 3     tags

# %%
# Show row counts for all tables in the current DuckDB connection
for table in con.sql("SHOW TABLES").df()["name"]:
    count = con.sql(f"SELECT COUNT(*) AS cnt FROM {table}").df()["cnt"][0]
    print(f"Table '{table}': {count} rows")
# Out:
# Table 'links': 86537 rows
# Table 'movies': 86537 rows
# Table 'ratings': 33832162 rows
# Table 'tags': 2328315 rows

# %% [markdown]
# ### Close the connection (when done)

# %%
con.close()
print("Connection closed.")
# Out:
# Connection closed.
